# %%
import pykep as pk
import numpy as np
pk.util.load_spice_kernel("/home/m/mmk40/Desktop/Planet Position/de431.bsp")
from pykep.orbit_plots import plot_planet, plot_lambert
from pykep import AU, DAY2SEC, SEC2DAY, DAY2YEAR
import pygmo as pg
from datetime import datetime, timedelta
import math

# %%
# Load planets
earth = pk.planet.spice('EARTH' , 'SUN', 'ECLIPJ2000', 'NONE')
jupiter = pk.planet.spice('JUPITER BARYCENTER', 'SUN', 'ECLIPJ2000', 'NONE' )

# Set launch window
start_date = pk.epoch_from_string("2035-01-01 00:00:00")
end_date = pk.epoch_from_string("2050-01-01 00:00:00")

# Parameters
launch_step = 30     # days between launch trials
tof_range = (300, 1500)  # in days, time of flight range

# %%
# Results list
results = []

# Scan through departure dates
t_dep = start_date
while t_dep.mjd2000 < end_date.mjd2000:
    rE, vE = earth.eph(t_dep)

    for tof_days in range(tof_range[0], tof_range[1], 30):  # try multiple TOFs
        try:
            t_arr = pk.epoch(t_dep.mjd2000 + tof_days)
            rJ, vJ = jupiter.eph(t_arr)

            dt_sec = tof_days * pk.DAY2SEC
            l1 = pk.lambert_problem(r1=rE, r2=rJ, tof=dt_sec, mu=pk.MU_SUN, max_revs=2)

            v1 = np.array(l1.get_v1()[0])
            v2 = np.array(l1.get_v2()[0])
            v_inf = (v1 - np.array(vE))/1000
            delta_v = (np.linalg.norm(v1 - np.array(vE)))/1000 
            v_arrival   = l1.get_v2()[0] # velocity of spacecraft at jupiter arrival
            hyperbolic_v_arrival   = (np.linalg.norm(np.array(v_arrival) - np.array(vJ)))/1000   # km/s  # substracting velocities and taking magnitude
            C3 = np.linalg.norm(v_inf) ** 2  # in km²/s²
            

            # Calculating Flyby speed

            rp = 9 * 69911e3 # m  # radius of periapsis for the flyby trajectory (change this)

            mu = 6.67e-11 * 1.898e27 # m3/s2  # gravitationalparameter for jupiter

            v_in = hyperbolic_v_arrival * 1000 # m/s # Jupiter arrival speed

            # Turning Angle
            phi = np.degrees(np.pi - 2 * np.acos (1/(((v_in**2)*rp)/mu + 1)))
            # print (np.pi) # Degree/radian check
            # print (f" Turning angle: {phi:.2f} degrees") # degrees


            # Law of Cosines to find the v_out
            #print(vJ) # vector/scalar check
            vJ_mag = np.linalg.norm(vJ)
            #print(vJ_mag)

            exit_speed = (math.sqrt((vJ_mag**2) + (v_in**2) - 2*vJ_mag*v_in*np.cos(phi)))/1000 # km/s
            #print(f"Flyby speed: {(exit_speed - hyperbolic_v_arrival):.2f} km/s")
            #print (f"Jupiter Departure Speed: {exit_speed:.2f} km/s")

            # Time to Heliopause from Jupiter flyby

            d = 194.8*AU # 200 AU in meters
            s = exit_speed*1000 # speed of space craft at jupiter exit in m/s 

            # print (d) .pk check

            time_to_200AU = (d/s)*SEC2DAY*DAY2YEAR
            total_time = time_to_200AU + tof_days/365
            flyby_speed = exit_speed - hyperbolic_v_arrival

            #print(f"Time to reach Jupiter: {dt*SEC2DAY*DAY2YEAR: .2f} years")
            #print(f"Time to 200 AU from Jupiter Flyby: {time_to_200AU:.2f} years")
            #print(f"Total Time to reach 200 AU from launch: {time_to_200AU + dt*SEC2DAY*DAY2YEAR : .2f} years")

            d1 = 84.8*AU
            s1 = exit_speed*1000

            time_to_90AU = (d1/s1)*SEC2DAY*DAY2YEAR # time to reach 90 AU

            d2 = 114.8*AU
            s2 = exit_speed*1000

            time_to_120AU = (d2/s2)*SEC2DAY*DAY2YEAR # time to reach 120 AU

            # Keplarian elements to Outgoing Asymptote
            # Function to convert v_inf_vec to RA and Dec
            def vector_to_ra_dec(vec):
                x, y, z = vec
                r = np.linalg.norm(vec)
                ra = np.arctan2(y, x)
                dec = np.arcsin(z / r)
                return np.degrees(ra) % 360, np.degrees(dec)



            # Compute outgoing asymptote direction
            v_inf_vec = (np.array(v_arrival) - np.array(vJ))  # Outgoing Asymptote Conditions at Jupiter arrival 
            v_inf_mag = np.linalg.norm(v_inf_vec) /1000 # km/s
            Outgoing_C3 = v_inf_mag**2 #km²/s²
            ra_inf, dec_inf = vector_to_ra_dec(v_inf_vec)

            

            if C3 <= 100:
                if flyby_speed > 0:
                    if total_time <= 75:

                        # Get Keplerian elements of transfer orbit
                        kep = pk.ic2par(rE, v1, pk.MU_SUN)  # r, v at arrival → orbital elements

                        results.append({
                            'departure': str(t_dep),
                            'arrival': str(t_arr),
                            'tof_days': tof_days,
                            'C3': C3,
                            'delta_v': delta_v,
                            'sma': kep[0],   # semi-major axis
                            'ecc': kep[1],   # eccentricity
                            'inc': np.degrees(kep[2]),  # inclination (rad → deg)
                            'raan': np.degrees(kep[3]),
                            'argp': np.degrees(kep[4]),
                            'ta': np.degrees(kep[5]),
                            'turning angle': phi,
                            'flyby speed': flyby_speed,
                            'jupiter departure speed': exit_speed,
                            'time_to_90AU': time_to_90AU,
                            'time_to_120AU': time_to_120AU,
                            'jupiter flyby to 200 au': time_to_200AU,
                            'total_time' : total_time,
                            'Outgoing_C3' : Outgoing_C3,
                            'ra_inf': ra_inf,
                            'dec_inf': dec_inf,
                    
                        })

        except RuntimeError as e:
            # Lambert solver may fail for some configurations; skip them
            continue

    t_dep = pk.epoch(t_dep.mjd2000 + launch_step)

# %%
# Sort by C3 (ascending)
results.sort(key=lambda x: x['total_time'])

# Print trajectories
for res in results[:]:
    print(f"Launch: {res['departure']}, Arrival: {res['arrival']}, C3: {res['C3']:.2f} km²/s², Delta v: {res['delta_v']:.2f} km/s \n\nTime to reach Jupiter: {res['tof_days']/365:.2f} years, Time to 200 AU from Jupiter Flyby: {res['jupiter flyby to 200 au']: .2f} years, Total Time to 200 AU from Launch: {res['total_time']:.2f} years\n")
    print(f"Time to reach 90 AU: {res['time_to_90AU']: .2f} years, Time to reach 120 AU: {res['time_to_120AU']: .2f} years\n")
    print(f"Turning angle: {res['turning angle']: .2f}° | Flyby Speed: {res['flyby speed']: .2f} km/s \n ")
    print(f"Elements for EARTH -> JUPITER → SMA: {res['sma']/1000:.3f} km, ECC: {res['ecc']:.4f}, INC: {res['inc']:.2f}°\n")
    print(f"Elements EARTH -> JUPITER → RAAN: {res['raan']:.3f}° , AP: {res['argp']:.4f}°, TA: {res['ta']:.2f}°\n\n\n")
    #print(f"GMAT Outgoing Asymptote:")
    #print(f"  Outgoing_C3: {res['Outgoing_C3']:.2f} km²/s² | RA: {res['ra_inf']:.2f} deg | DEC: {res['dec_inf']:.2f} deg\n\n\n ")
# Out:
# Launch: 2043-Feb-18 00:00:00, Arrival: 2044-Sep-10 00:00:00, C3: 98.75 km²/s², Delta v: 9.94 km/s
#
# Time to reach Jupiter: 1.56 years, Time to 200 AU from Jupiter Flyby:  38.47 years, Total Time to 200 AU from Launch: 40.03 years
#
# Time to reach 90 AU:  16.75 years, Time to reach 120 AU:  22.67 years
#
# Turning angle:  78.32° | Flyby Speed:  13.17 km/s
#
# Elements for EARTH -> JUPITER → SMA: 622721025.402 km, ECC: 0.7634, INC: 1.41°
#
# Elements EARTH -> JUPITER → RAAN: 328.506° , AP: 187.1696°, TA: -2.59°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2045-Nov-04 00:00:00, C3: 98.58 km²/s², Delta v: 9.93 km/s
#
# Time to reach Jupiter: 1.56 years, Time to 200 AU from Jupiter Flyby:  39.50 years, Total Time to 200 AU from Launch: 41.07 years
#
# Time to reach 90 AU:  17.20 years, Time to reach 120 AU:  23.28 years
#
# Turning angle:  84.62° | Flyby Speed:  13.49 km/s
#
# Elements for EARTH -> JUPITER → SMA: 564003636.161 km, ECC: 0.7370, INC: 1.77°
#
# Elements EARTH -> JUPITER → RAAN: 23.194° , AP: 166.6990°, TA: 5.16°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2046-Dec-29 00:00:00, C3: 90.52 km²/s², Delta v: 9.51 km/s
#
# Time to reach Jupiter: 1.64 years, Time to 200 AU from Jupiter Flyby:  40.73 years, Total Time to 200 AU from Launch: 42.38 years
#
# Time to reach 90 AU:  17.73 years, Time to reach 120 AU:  24.00 years
#
# Turning angle:  91.01° | Flyby Speed:  13.68 km/s
#
# Elements for EARTH -> JUPITER → SMA: 536311907.741 km, ECC: 0.7185, INC: 2.88°
#
# Elements EARTH -> JUPITER → RAAN: 47.286° , AP: 178.8158°, TA: 0.44°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2049-Mar-18 00:00:00, C3: 94.00 km²/s², Delta v: 9.70 km/s
#
# Time to reach Jupiter: 1.64 years, Time to 200 AU from Jupiter Flyby:  41.85 years, Total Time to 200 AU from Launch: 43.50 years
#
# Time to reach 90 AU:  18.22 years, Time to reach 120 AU:  24.67 years
#
# Turning angle:  91.32° | Flyby Speed:  13.11 km/s
#
# Elements for EARTH -> JUPITER → SMA: 583997568.127 km, ECC: 0.7399, INC: 0.33°
#
# Elements EARTH -> JUPITER → RAAN: 124.138° , AP: 176.4246°, TA: 1.05°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2046-Nov-29 00:00:00, C3: 93.74 km²/s², Delta v: 9.68 km/s
#
# Time to reach Jupiter: 1.56 years, Time to 200 AU from Jupiter Flyby:  42.31 years, Total Time to 200 AU from Launch: 43.87 years
#
# Time to reach 90 AU:  18.42 years, Time to reach 120 AU:  24.93 years
#
# Turning angle:  85.58° | Flyby Speed:  12.08 km/s
#
# Elements for EARTH -> JUPITER → SMA: 570426751.140 km, ECC: 0.7353, INC: 2.65°
#
# Elements EARTH -> JUPITER → RAAN: 47.294° , AP: 179.2926°, TA: 0.24°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2037-Apr-20 00:00:00, C3: 97.47 km²/s², Delta v: 9.87 km/s
#
# Time to reach Jupiter: 1.73 years, Time to 200 AU from Jupiter Flyby:  43.17 years, Total Time to 200 AU from Launch: 44.89 years
#
# Time to reach 90 AU:  18.79 years, Time to reach 120 AU:  25.44 years
#
# Turning angle:  97.40° | Flyby Speed:  13.23 km/s
#
# Elements for EARTH -> JUPITER → SMA: 544081245.773 km, ECC: 0.7229, INC: 0.35°
#
# Elements EARTH -> JUPITER → RAAN: 126.829° , AP: 168.5396°, TA: 4.36°
#
#
#
# Launch: 2043-Feb-18 00:00:00, Arrival: 2044-Oct-10 00:00:00, C3: 93.79 km²/s², Delta v: 9.68 km/s
#
# Time to reach Jupiter: 1.64 years, Time to 200 AU from Jupiter Flyby:  43.45 years, Total Time to 200 AU from Launch: 45.09 years
#
# Time to reach 90 AU:  18.91 years, Time to reach 120 AU:  25.61 years
#
# Turning angle:  83.97° | Flyby Speed:  11.27 km/s
#
# Elements for EARTH -> JUPITER → SMA: 573841046.422 km, ECC: 0.7431, INC: 1.72°
#
# Elements EARTH -> JUPITER → RAAN: 328.526° , AP: 186.4073°, TA: -2.43°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2042-Oct-21 00:00:00, C3: 90.38 km²/s², Delta v: 9.51 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  43.80 years, Total Time to 200 AU from Launch: 45.61 years
#
# Time to reach 90 AU:  19.07 years, Time to reach 120 AU:  25.81 years
#
# Turning angle:  91.57° | Flyby Speed:  12.16 km/s
#
# Elements for EARTH -> JUPITER → SMA: 562858324.199 km, ECC: 0.7394, INC: 1.38°
#
# Elements EARTH -> JUPITER → RAAN: 98.540° , AP: 353.1947°, TA: 2.55°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2043-Dec-15 00:00:00, C3: 81.95 km²/s², Delta v: 9.05 km/s
#
# Time to reach Jupiter: 1.89 years, Time to 200 AU from Jupiter Flyby:  44.42 years, Total Time to 200 AU from Launch: 46.31 years
#
# Time to reach 90 AU:  19.34 years, Time to reach 120 AU:  26.18 years
#
# Turning angle:  96.95° | Flyby Speed:  12.57 km/s
#
# Elements for EARTH -> JUPITER → SMA: 516847394.008 km, ECC: 0.7151, INC: 0.14°
#
# Elements EARTH -> JUPITER → RAAN: 301.873° , AP: 179.9527°, TA: 0.70°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2046-Mar-04 00:00:00, C3: 89.68 km²/s², Delta v: 9.47 km/s
#
# Time to reach Jupiter: 1.89 years, Time to 200 AU from Jupiter Flyby:  44.82 years, Total Time to 200 AU from Launch: 46.71 years
#
# Time to reach 90 AU:  19.51 years, Time to reach 120 AU:  26.41 years
#
# Turning angle:  103.21° | Flyby Speed:  13.15 km/s
#
# Elements for EARTH -> JUPITER → SMA: 476363553.099 km, ECC: 0.6890, INC: 2.51°
#
# Elements EARTH -> JUPITER → RAAN: 23.167° , AP: 165.9303°, TA: 6.04°
#
#
#
# Launch: 2048-Aug-20 00:00:00, Arrival: 2050-Jun-11 00:00:00, C3: 95.10 km²/s², Delta v: 9.75 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  45.08 years, Total Time to 200 AU from Launch: 46.89 years
#
# Time to reach 90 AU:  19.63 years, Time to reach 120 AU:  26.57 years
#
# Turning angle:  96.91° | Flyby Speed:  12.26 km/s
#
# Elements for EARTH -> JUPITER → SMA: 567339910.575 km, ECC: 0.7341, INC: 2.23°
#
# Elements EARTH -> JUPITER → RAAN: 326.917° , AP: 7.3860°, TA: -2.87°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2046-Oct-30 00:00:00, C3: 98.15 km²/s², Delta v: 9.91 km/s
#
# Time to reach Jupiter: 1.48 years, Time to 200 AU from Jupiter Flyby:  45.45 years, Total Time to 200 AU from Launch: 46.93 years
#
# Time to reach 90 AU:  19.78 years, Time to reach 120 AU:  26.78 years
#
# Turning angle:  79.71° | Flyby Speed:  9.70 km/s
#
# Elements for EARTH -> JUPITER → SMA: 620092553.409 km, ECC: 0.7565, INC: 2.46°
#
# Elements EARTH -> JUPITER → RAAN: 47.302° , AP: 179.9997°, TA: -0.04°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2047-Mar-29 00:00:00, C3: 86.30 km²/s², Delta v: 9.29 km/s
#
# Time to reach Jupiter: 1.89 years, Time to 200 AU from Jupiter Flyby:  45.06 years, Total Time to 200 AU from Launch: 46.95 years
#
# Time to reach 90 AU:  19.61 years, Time to reach 120 AU:  26.55 years
#
# Turning angle:  104.15° | Flyby Speed:  13.15 km/s
#
# Elements for EARTH -> JUPITER → SMA: 481106559.874 km, ECC: 0.6862, INC: 3.97°
#
# Elements EARTH -> JUPITER → RAAN: 47.261° , AP: 178.6354°, TA: 0.56°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2047-May-28 00:00:00, C3: 88.75 km²/s², Delta v: 9.42 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  45.40 years, Total Time to 200 AU from Launch: 47.45 years
#
# Time to reach 90 AU:  19.76 years, Time to reach 120 AU:  26.75 years
#
# Turning angle:  109.97° | Flyby Speed:  13.67 km/s
#
# Elements for EARTH -> JUPITER → SMA: 464023529.268 km, ECC: 0.6747, INC: 5.43°
#
# Elements EARTH -> JUPITER → RAAN: 47.243° , AP: 179.4069°, TA: 0.24°
#
#
#
# Launch: 2043-Mar-20 00:00:00, Arrival: 2046-Dec-29 00:00:00, C3: 86.91 km²/s², Delta v: 9.32 km/s
#
# Time to reach Jupiter: 3.78 years, Time to 200 AU from Jupiter Flyby:  43.82 years, Total Time to 200 AU from Launch: 47.60 years
#
# Time to reach 90 AU:  19.07 years, Time to reach 120 AU:  25.82 years
#
# Turning angle:  103.75° | Flyby Speed:  13.69 km/s
#
# Elements for EARTH -> JUPITER → SMA: 475832520.489 km, ECC: 0.6878, INC: 3.39°
#
# Elements EARTH -> JUPITER → RAAN: 178.676° , AP: 6.4268°, TA: -2.77°
#
#
#
# Launch: 2042-Feb-23 00:00:00, Arrival: 2046-Feb-02 00:00:00, C3: 85.01 km²/s², Delta v: 9.22 km/s
#
# Time to reach Jupiter: 3.95 years, Time to 200 AU from Jupiter Flyby:  43.96 years, Total Time to 200 AU from Launch: 47.90 years
#
# Time to reach 90 AU:  19.14 years, Time to reach 120 AU:  25.91 years
#
# Turning angle:  103.52° | Flyby Speed:  13.59 km/s
#
# Elements for EARTH -> JUPITER → SMA: 483670556.718 km, ECC: 0.6940, INC: 4.23°
#
# Elements EARTH -> JUPITER → RAAN: 153.936° , AP: 359.6929°, TA: 0.12°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2048-Jun-21 00:00:00, C3: 95.34 km²/s², Delta v: 9.76 km/s
#
# Time to reach Jupiter: 1.97 years, Time to 200 AU from Jupiter Flyby:  46.25 years, Total Time to 200 AU from Launch: 48.22 years
#
# Time to reach 90 AU:  20.13 years, Time to reach 120 AU:  27.26 years
#
# Turning angle:  109.66° | Flyby Speed:  13.26 km/s
#
# Elements for EARTH -> JUPITER → SMA: 478365176.020 km, ECC: 0.6869, INC: 1.33°
#
# Elements EARTH -> JUPITER → RAAN: 99.921° , AP: 164.0572°, TA: 6.80°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2049-Feb-16 00:00:00, C3: 97.67 km²/s², Delta v: 9.88 km/s
#
# Time to reach Jupiter: 1.56 years, Time to 200 AU from Jupiter Flyby:  46.80 years, Total Time to 200 AU from Launch: 48.36 years
#
# Time to reach 90 AU:  20.37 years, Time to reach 120 AU:  27.58 years
#
# Turning angle:  85.91° | Flyby Speed:  10.03 km/s
#
# Elements for EARTH -> JUPITER → SMA: 626576694.157 km, ECC: 0.7576, INC: 0.41°
#
# Elements EARTH -> JUPITER → RAAN: 123.966° , AP: 177.1338°, TA: 0.81°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2048-Apr-22 00:00:00, C3: 99.58 km²/s², Delta v: 9.98 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  46.61 years, Total Time to 200 AU from Launch: 48.41 years
#
# Time to reach 90 AU:  20.29 years, Time to reach 120 AU:  27.47 years
#
# Turning angle:  102.97° | Flyby Speed:  12.33 km/s
#
# Elements for EARTH -> JUPITER → SMA: 499401361.736 km, ECC: 0.7005, INC: 1.32°
#
# Elements EARTH -> JUPITER → RAAN: 99.922° , AP: 163.4603°, TA: 6.88°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2043-Jan-19 00:00:00, C3: 84.50 km²/s², Delta v: 9.19 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  46.60 years, Total Time to 200 AU from Launch: 48.65 years
#
# Time to reach 90 AU:  20.28 years, Time to reach 120 AU:  27.46 years
#
# Turning angle:  104.04° | Flyby Speed:  12.47 km/s
#
# Elements for EARTH -> JUPITER → SMA: 505618149.335 km, ECC: 0.7100, INC: 1.41°
#
# Elements EARTH -> JUPITER → RAAN: 98.536° , AP: 352.6842°, TA: 2.93°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2045-Dec-04 00:00:00, C3: 95.67 km²/s², Delta v: 9.78 km/s
#
# Time to reach Jupiter: 1.64 years, Time to 200 AU from Jupiter Flyby:  47.09 years, Total Time to 200 AU from Launch: 48.74 years
#
# Time to reach 90 AU:  20.50 years, Time to reach 120 AU:  27.75 years
#
# Turning angle:  90.02° | Flyby Speed:  10.48 km/s
#
# Elements for EARTH -> JUPITER → SMA: 530557717.111 km, ECC: 0.7207, INC: 1.92°
#
# Elements EARTH -> JUPITER → RAAN: 23.187° , AP: 166.1742°, TA: 5.56°
#
#
#
# Launch: 2036-Aug-23 00:00:00, Arrival: 2038-Jun-14 00:00:00, C3: 90.98 km²/s², Delta v: 9.54 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  47.00 years, Total Time to 200 AU from Launch: 48.81 years
#
# Time to reach 90 AU:  20.46 years, Time to reach 120 AU:  27.70 years
#
# Turning angle:  98.11° | Flyby Speed:  11.57 km/s
#
# Elements for EARTH -> JUPITER → SMA: 560157193.583 km, ECC: 0.7299, INC: 1.43°
#
# Elements EARTH -> JUPITER → RAAN: 329.875° , AP: 0.1061°, TA: -0.01°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2047-Jul-27 00:00:00, C3: 86.92 km²/s², Delta v: 9.32 km/s
#
# Time to reach Jupiter: 3.29 years, Time to 200 AU from Jupiter Flyby:  45.68 years, Total Time to 200 AU from Launch: 48.96 years
#
# Time to reach 90 AU:  19.88 years, Time to reach 120 AU:  26.92 years
#
# Turning angle:  109.71° | Flyby Speed:  13.52 km/s
#
# Elements for EARTH -> JUPITER → SMA: 459559134.039 km, ECC: 0.6745, INC: 3.87°
#
# Elements EARTH -> JUPITER → RAAN: 203.062° , AP: 6.6135°, TA: -2.90°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2046-May-03 00:00:00, C3: 87.31 km²/s², Delta v: 9.34 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  47.59 years, Total Time to 200 AU from Launch: 49.65 years
#
# Time to reach 90 AU:  20.72 years, Time to reach 120 AU:  28.05 years
#
# Turning angle:  109.28° | Flyby Speed:  12.66 km/s
#
# Elements for EARTH -> JUPITER → SMA: 459601550.304 km, ECC: 0.6772, INC: 3.11°
#
# Elements EARTH -> JUPITER → RAAN: 23.155° , AP: 166.7083°, TA: 5.83°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2041-Oct-26 00:00:00, C3: 97.91 km²/s², Delta v: 9.89 km/s
#
# Time to reach Jupiter: 1.89 years, Time to 200 AU from Jupiter Flyby:  47.89 years, Total Time to 200 AU from Launch: 49.78 years
#
# Time to reach 90 AU:  20.85 years, Time to reach 120 AU:  28.22 years
#
# Turning angle:  96.61° | Flyby Speed:  11.02 km/s
#
# Elements for EARTH -> JUPITER → SMA: 553520721.077 km, ECC: 0.7359, INC: 2.10°
#
# Elements EARTH -> JUPITER → RAAN: 73.295° , AP: 348.5481°, TA: 4.42°
#
#
#
# Launch: 2045-Jun-07 00:00:00, Arrival: 2049-May-17 00:00:00, C3: 86.64 km²/s², Delta v: 9.31 km/s
#
# Time to reach Jupiter: 3.95 years, Time to 200 AU from Jupiter Flyby:  45.84 years, Total Time to 200 AU from Launch: 49.79 years
#
# Time to reach 90 AU:  19.96 years, Time to reach 120 AU:  27.02 years
#
# Turning angle:  104.08° | Flyby Speed:  12.79 km/s
#
# Elements for EARTH -> JUPITER → SMA: 491762694.131 km, ECC: 0.6922, INC: 0.14°
#
# Elements EARTH -> JUPITER → RAAN: 253.604° , AP: 9.3514°, TA: -2.95°
#
#
#
# Launch: 2045-Jun-07 00:00:00, Arrival: 2049-Jun-16 00:00:00, C3: 89.15 km²/s², Delta v: 9.44 km/s
#
# Time to reach Jupiter: 4.03 years, Time to 200 AU from Jupiter Flyby:  45.87 years, Total Time to 200 AU from Launch: 49.89 years
#
# Time to reach 90 AU:  19.97 years, Time to reach 120 AU:  27.03 years
#
# Turning angle:  103.23° | Flyby Speed:  12.68 km/s
#
# Elements for EARTH -> JUPITER → SMA: 495133419.904 km, ECC: 0.6949, INC: 0.02°
#
# Elements EARTH -> JUPITER → RAAN: 96.463° , AP: 168.4671°, TA: -3.78°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2043-Mar-20 00:00:00, C3: 81.74 km²/s², Delta v: 9.04 km/s
#
# Time to reach Jupiter: 2.22 years, Time to 200 AU from Jupiter Flyby:  47.79 years, Total Time to 200 AU from Launch: 50.01 years
#
# Time to reach 90 AU:  20.80 years, Time to reach 120 AU:  28.16 years
#
# Turning angle:  110.21° | Flyby Speed:  12.68 km/s
#
# Elements for EARTH -> JUPITER → SMA: 486315018.733 km, ECC: 0.6983, INC: 1.45°
#
# Elements EARTH -> JUPITER → RAAN: 98.531° , AP: 353.1064°, TA: 2.82°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2044-Apr-13 00:00:00, C3: 77.11 km²/s², Delta v: 8.78 km/s
#
# Time to reach Jupiter: 2.22 years, Time to 200 AU from Jupiter Flyby:  47.82 years, Total Time to 200 AU from Launch: 50.04 years
#
# Time to reach 90 AU:  20.82 years, Time to reach 120 AU:  28.18 years
#
# Turning angle:  110.42° | Flyby Speed:  12.69 km/s
#
# Elements for EARTH -> JUPITER → SMA: 471751774.327 km, ECC: 0.6879, INC: 1.48°
#
# Elements EARTH -> JUPITER → RAAN: 303.371° , AP: 179.0457°, TA: 0.48°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2045-Aug-06 00:00:00, C3: 99.16 km²/s², Delta v: 9.96 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  46.61 years, Total Time to 200 AU from Launch: 50.14 years
#
# Time to reach 90 AU:  20.29 years, Time to reach 120 AU:  27.47 years
#
# Turning angle:  109.50° | Flyby Speed:  13.09 km/s
#
# Elements for EARTH -> JUPITER → SMA: 466960557.771 km, ECC: 0.6912, INC: 2.05°
#
# Elements EARTH -> JUPITER → RAAN: 123.650° , AP: 18.2991°, TA: -7.92°
#
#
#
# Launch: 2043-Feb-18 00:00:00, Arrival: 2045-Jan-08 00:00:00, C3: 87.42 km²/s², Delta v: 9.35 km/s
#
# Time to reach Jupiter: 1.89 years, Time to 200 AU from Jupiter Flyby:  48.27 years, Total Time to 200 AU from Launch: 50.16 years
#
# Time to reach 90 AU:  21.01 years, Time to reach 120 AU:  28.44 years
#
# Turning angle:  98.36° | Flyby Speed:  11.09 km/s
#
# Elements for EARTH -> JUPITER → SMA: 496891587.431 km, ECC: 0.7030, INC: 3.44°
#
# Elements EARTH -> JUPITER → RAAN: 328.572° , AP: 185.3463°, TA: -2.21°
#
#
#
# Launch: 2043-Feb-18 00:00:00, Arrival: 2045-Nov-04 00:00:00, C3: 92.40 km²/s², Delta v: 9.61 km/s
#
# Time to reach Jupiter: 2.71 years, Time to 200 AU from Jupiter Flyby:  47.55 years, Total Time to 200 AU from Launch: 50.27 years
#
# Time to reach 90 AU:  20.70 years, Time to reach 120 AU:  28.02 years
#
# Turning angle:  115.93° | Flyby Speed:  13.41 km/s
#
# Elements for EARTH -> JUPITER → SMA: 446940086.422 km, ECC: 0.6722, INC: 4.76°
#
# Elements EARTH -> JUPITER → RAAN: 148.650° , AP: 12.0949°, TA: -5.39°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2048-Sep-19 00:00:00, C3: 89.80 km²/s², Delta v: 9.48 km/s
#
# Time to reach Jupiter: 2.22 years, Time to 200 AU from Jupiter Flyby:  48.08 years, Total Time to 200 AU from Launch: 50.30 years
#
# Time to reach 90 AU:  20.93 years, Time to reach 120 AU:  28.33 years
#
# Turning angle:  115.94° | Flyby Speed:  13.20 km/s
#
# Elements for EARTH -> JUPITER → SMA: 463390434.433 km, ECC: 0.6756, INC: 1.34°
#
# Elements EARTH -> JUPITER → RAAN: 99.919° , AP: 166.0203°, TA: 6.07°
#
#
#
# Launch: 2045-Jun-07 00:00:00, Arrival: 2048-Feb-22 00:00:00, C3: 98.78 km²/s², Delta v: 9.94 km/s
#
# Time to reach Jupiter: 2.71 years, Time to 200 AU from Jupiter Flyby:  47.76 years, Total Time to 200 AU from Launch: 50.47 years
#
# Time to reach 90 AU:  20.79 years, Time to reach 120 AU:  28.14 years
#
# Turning angle:  115.91° | Flyby Speed:  13.32 km/s
#
# Elements for EARTH -> JUPITER → SMA: 450122594.895 km, ECC: 0.6707, INC: 2.93°
#
# Elements EARTH -> JUPITER → RAAN: 76.157° , AP: 160.1826°, TA: 8.82°
#
#
#
# Launch: 2043-Feb-18 00:00:00, Arrival: 2045-Oct-05 00:00:00, C3: 94.19 km²/s², Delta v: 9.71 km/s
#
# Time to reach Jupiter: 2.63 years, Time to 200 AU from Jupiter Flyby:  47.99 years, Total Time to 200 AU from Launch: 50.62 years
#
# Time to reach 90 AU:  20.89 years, Time to reach 120 AU:  28.28 years
#
# Turning angle:  115.81° | Flyby Speed:  13.22 km/s
#
# Elements for EARTH -> JUPITER → SMA: 447119323.168 km, ECC: 0.6718, INC: 5.72°
#
# Elements EARTH -> JUPITER → RAAN: 148.644° , AP: 10.9057°, TA: -4.86°
#
#
#
# Launch: 2043-Mar-20 00:00:00, Arrival: 2045-Oct-05 00:00:00, C3: 94.36 km²/s², Delta v: 9.71 km/s
#
# Time to reach Jupiter: 2.55 years, Time to 200 AU from Jupiter Flyby:  48.11 years, Total Time to 200 AU from Launch: 50.66 years
#
# Time to reach 90 AU:  20.95 years, Time to reach 120 AU:  28.35 years
#
# Turning angle:  115.78° | Flyby Speed:  13.17 km/s
#
# Elements for EARTH -> JUPITER → SMA: 446573835.600 km, ECC: 0.6738, INC: 3.48°
#
# Elements EARTH -> JUPITER → RAAN: 358.682° , AP: 161.0550°, TA: 8.42°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2041-Sep-26 00:00:00, C3: 99.99 km²/s², Delta v: 10.00 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  48.87 years, Total Time to 200 AU from Launch: 50.68 years
#
# Time to reach 90 AU:  21.28 years, Time to reach 120 AU:  28.80 years
#
# Turning angle:  92.09° | Flyby Speed:  10.05 km/s
#
# Elements for EARTH -> JUPITER → SMA: 579619356.162 km, ECC: 0.7476, INC: 2.02°
#
# Elements EARTH -> JUPITER → RAAN: 73.301° , AP: 348.8884°, TA: 4.18°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2037-Oct-17 00:00:00, C3: 86.78 km²/s², Delta v: 9.32 km/s
#
# Time to reach Jupiter: 2.22 years, Time to 200 AU from Jupiter Flyby:  48.54 years, Total Time to 200 AU from Launch: 50.76 years
#
# Time to reach 90 AU:  21.13 years, Time to reach 120 AU:  28.61 years
#
# Turning angle:  116.10° | Flyby Speed:  13.03 km/s
#
# Elements for EARTH -> JUPITER → SMA: 478020456.020 km, ECC: 0.6839, INC: 0.44°
#
# Elements EARTH -> JUPITER → RAAN: 305.731° , AP: 351.3307°, TA: 3.97°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2045-Feb-07 00:00:00, C3: 82.98 km²/s², Delta v: 9.11 km/s
#
# Time to reach Jupiter: 3.04 years, Time to 200 AU from Jupiter Flyby:  47.75 years, Total Time to 200 AU from Launch: 50.79 years
#
# Time to reach 90 AU:  20.79 years, Time to reach 120 AU:  28.14 years
#
# Turning angle:  116.03° | Flyby Speed:  13.34 km/s
#
# Elements for EARTH -> JUPITER → SMA: 456525277.308 km, ECC: 0.6789, INC: 3.11°
#
# Elements EARTH -> JUPITER → RAAN: 123.611° , AP: 8.6593°, TA: -3.83°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2050-Mar-13 00:00:00, C3: 90.79 km²/s², Delta v: 9.53 km/s
#
# Time to reach Jupiter: 3.70 years, Time to 200 AU from Jupiter Flyby:  47.20 years, Total Time to 200 AU from Launch: 50.90 years
#
# Time to reach 90 AU:  20.55 years, Time to reach 120 AU:  27.82 years
#
# Turning angle:  109.85° | Flyby Speed:  12.88 km/s
#
# Elements for EARTH -> JUPITER → SMA: 487440474.207 km, ECC: 0.6906, INC: 1.27°
#
# Elements EARTH -> JUPITER → RAAN: 99.933° , AP: 191.3409°, TA: -4.98°
#
#
#
# Launch: 2043-Mar-20 00:00:00, Arrival: 2045-Nov-04 00:00:00, C3: 93.90 km²/s², Delta v: 9.69 km/s
#
# Time to reach Jupiter: 2.63 years, Time to 200 AU from Jupiter Flyby:  48.29 years, Total Time to 200 AU from Launch: 50.92 years
#
# Time to reach 90 AU:  21.02 years, Time to reach 120 AU:  28.46 years
#
# Turning angle:  115.74° | Flyby Speed:  13.09 km/s
#
# Elements for EARTH -> JUPITER → SMA: 446613807.851 km, ECC: 0.6729, INC: 4.15°
#
# Elements EARTH -> JUPITER → RAAN: 358.681° , AP: 162.2870°, TA: 7.88°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2047-Jun-27 00:00:00, C3: 87.43 km²/s², Delta v: 9.35 km/s
#
# Time to reach Jupiter: 3.21 years, Time to 200 AU from Jupiter Flyby:  47.83 years, Total Time to 200 AU from Launch: 51.03 years
#
# Time to reach 90 AU:  20.82 years, Time to reach 120 AU:  28.18 years
#
# Turning angle:  110.61° | Flyby Speed:  12.71 km/s
#
# Elements for EARTH -> JUPITER → SMA: 457066139.407 km, ECC: 0.6723, INC: 4.71°
#
# Elements EARTH -> JUPITER → RAAN: 203.070° , AP: 4.8141°, TA: -2.12°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2048-Jan-23 00:00:00, C3: 92.69 km²/s², Delta v: 9.63 km/s
#
# Time to reach Jupiter: 2.71 years, Time to 200 AU from Jupiter Flyby:  48.33 years, Total Time to 200 AU from Launch: 51.04 years
#
# Time to reach 90 AU:  21.04 years, Time to reach 120 AU:  28.48 years
#
# Turning angle:  115.76° | Flyby Speed:  13.08 km/s
#
# Elements for EARTH -> JUPITER → SMA: 450147935.558 km, ECC: 0.6658, INC: 5.70°
#
# Elements EARTH -> JUPITER → RAAN: 227.146° , AP: 7.6470°, TA: -3.41°
#
#
#
# Launch: 2040-Jan-05 00:00:00, Arrival: 2043-Nov-15 00:00:00, C3: 98.21 km²/s², Delta v: 9.91 km/s
#
# Time to reach Jupiter: 3.86 years, Time to 200 AU from Jupiter Flyby:  47.20 years, Total Time to 200 AU from Launch: 51.07 years
#
# Time to reach 90 AU:  20.55 years, Time to reach 120 AU:  27.82 years
#
# Turning angle:  110.19° | Flyby Speed:  12.92 km/s
#
# Elements for EARTH -> JUPITER → SMA: 491000163.593 km, ECC: 0.7063, INC: 0.06°
#
# Elements EARTH -> JUPITER → RAAN: 108.281° , AP: 337.6653°, TA: 7.41°
#
#
#
# Launch: 2048-Aug-20 00:00:00, Arrival: 2050-May-12 00:00:00, C3: 97.72 km²/s², Delta v: 9.89 km/s
#
# Time to reach Jupiter: 1.73 years, Time to 200 AU from Jupiter Flyby:  49.38 years, Total Time to 200 AU from Launch: 51.11 years
#
# Time to reach 90 AU:  21.50 years, Time to reach 120 AU:  29.10 years
#
# Turning angle:  92.19° | Flyby Speed:  9.87 km/s
#
# Elements for EARTH -> JUPITER → SMA: 597354092.748 km, ECC: 0.7476, INC: 1.81°
#
# Elements EARTH -> JUPITER → RAAN: 326.900° , AP: 7.7304°, TA: -2.91°
#
#
#
# Launch: 2037-Sep-17 00:00:00, Arrival: 2039-Aug-08 00:00:00, C3: 99.00 km²/s², Delta v: 9.95 km/s
#
# Time to reach Jupiter: 1.89 years, Time to 200 AU from Jupiter Flyby:  49.41 years, Total Time to 200 AU from Launch: 51.30 years
#
# Time to reach 90 AU:  21.51 years, Time to reach 120 AU:  29.12 years
#
# Turning angle:  98.29° | Flyby Speed:  10.64 km/s
#
# Elements for EARTH -> JUPITER → SMA: 564382602.333 km, ECC: 0.7346, INC: 4.44°
#
# Elements EARTH -> JUPITER → RAAN: 353.938° , AP: 7.9530°, TA: -3.11°
#
#
#
# Launch: 2043-Feb-18 00:00:00, Arrival: 2045-Dec-04 00:00:00, C3: 92.51 km²/s², Delta v: 9.62 km/s
#
# Time to reach Jupiter: 2.79 years, Time to 200 AU from Jupiter Flyby:  48.56 years, Total Time to 200 AU from Launch: 51.35 years
#
# Time to reach 90 AU:  21.14 years, Time to reach 120 AU:  28.62 years
#
# Turning angle:  115.68° | Flyby Speed:  12.98 km/s
#
# Elements for EARTH -> JUPITER → SMA: 447231257.446 km, ECC: 0.6731, INC: 4.11°
#
# Elements EARTH -> JUPITER → RAAN: 148.655° , AP: 13.3771°, TA: -5.95°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2043-Jun-18 00:00:00, C3: 78.68 km²/s², Delta v: 8.87 km/s
#
# Time to reach Jupiter: 2.47 years, Time to 200 AU from Jupiter Flyby:  48.92 years, Total Time to 200 AU from Launch: 51.38 years
#
# Time to reach 90 AU:  21.29 years, Time to reach 120 AU:  28.83 years
#
# Turning angle:  116.26° | Flyby Speed:  12.90 km/s
#
# Elements for EARTH -> JUPITER → SMA: 471102316.715 km, ECC: 0.6882, INC: 1.55°
#
# Elements EARTH -> JUPITER → RAAN: 98.517° , AP: 354.6850°, TA: 2.20°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2044-Oct-10 00:00:00, C3: 92.54 km²/s², Delta v: 9.62 km/s
#
# Time to reach Jupiter: 3.78 years, Time to 200 AU from Jupiter Flyby:  47.66 years, Total Time to 200 AU from Launch: 51.44 years
#
# Time to reach 90 AU:  20.75 years, Time to reach 120 AU:  28.09 years
#
# Turning angle:  109.40° | Flyby Speed:  12.64 km/s
#
# Elements for EARTH -> JUPITER → SMA: 480355050.501 km, ECC: 0.6984, INC: 1.22°
#
# Elements EARTH -> JUPITER → RAAN: 98.569° , AP: 15.4210°, TA: -6.63°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2044-Apr-13 00:00:00, C3: 78.27 km²/s², Delta v: 8.85 km/s
#
# Time to reach Jupiter: 3.29 years, Time to 200 AU from Jupiter Flyby:  48.22 years, Total Time to 200 AU from Launch: 51.51 years
#
# Time to reach 90 AU:  20.99 years, Time to reach 120 AU:  28.42 years
#
# Turning angle:  116.20° | Flyby Speed:  13.17 km/s
#
# Elements for EARTH -> JUPITER → SMA: 468555346.407 km, ECC: 0.6867, INC: 1.12°
#
# Elements EARTH -> JUPITER → RAAN: 98.590° , AP: 5.6822°, TA: -2.56°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2048-Feb-22 00:00:00, C3: 89.37 km²/s², Delta v: 9.45 km/s
#
# Time to reach Jupiter: 2.79 years, Time to 200 AU from Jupiter Flyby:  48.86 years, Total Time to 200 AU from Launch: 51.66 years
#
# Time to reach 90 AU:  21.27 years, Time to reach 120 AU:  28.80 years
#
# Turning angle:  115.66° | Flyby Speed:  12.86 km/s
#
# Elements for EARTH -> JUPITER → SMA: 451230891.284 km, ECC: 0.6671, INC: 4.20°
#
# Elements EARTH -> JUPITER → RAAN: 227.129° , AP: 9.0550°, TA: -4.02°
#
#
#
# Launch: 2036-Aug-23 00:00:00, Arrival: 2038-Sep-12 00:00:00, C3: 87.10 km²/s², Delta v: 9.33 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  49.62 years, Total Time to 200 AU from Launch: 51.67 years
#
# Time to reach 90 AU:  21.60 years, Time to reach 120 AU:  29.24 years
#
# Turning angle:  109.31° | Flyby Speed:  11.87 km/s
#
# Elements for EARTH -> JUPITER → SMA: 511832534.221 km, ECC: 0.7044, INC: 2.53°
#
# Elements EARTH -> JUPITER → RAAN: 329.910° , AP: 0.1073°, TA: -0.03°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2044-Oct-10 00:00:00, C3: 95.69 km²/s², Delta v: 9.78 km/s
#
# Time to reach Jupiter: 2.71 years, Time to 200 AU from Jupiter Flyby:  48.97 years, Total Time to 200 AU from Launch: 51.68 years
#
# Time to reach 90 AU:  21.32 years, Time to reach 120 AU:  28.86 years
#
# Turning angle:  116.68° | Flyby Speed:  12.93 km/s
#
# Elements for EARTH -> JUPITER → SMA: 454945548.577 km, ECC: 0.6766, INC: 7.58°
#
# Elements EARTH -> JUPITER → RAAN: 123.565° , AP: 3.6633°, TA: -1.62°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2045-Jan-08 00:00:00, C3: 82.41 km²/s², Delta v: 9.08 km/s
#
# Time to reach Jupiter: 2.96 years, Time to 200 AU from Jupiter Flyby:  48.77 years, Total Time to 200 AU from Launch: 51.73 years
#
# Time to reach 90 AU:  21.23 years, Time to reach 120 AU:  28.74 years
#
# Turning angle:  116.68° | Flyby Speed:  13.00 km/s
#
# Elements for EARTH -> JUPITER → SMA: 455584966.003 km, ECC: 0.6778, INC: 3.53°
#
# Elements EARTH -> JUPITER → RAAN: 123.601° , AP: 7.2881°, TA: -3.23°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2049-Apr-17 00:00:00, C3: 91.07 km²/s², Delta v: 9.54 km/s
#
# Time to reach Jupiter: 1.73 years, Time to 200 AU from Jupiter Flyby:  50.11 years, Total Time to 200 AU from Launch: 51.83 years
#
# Time to reach 90 AU:  21.81 years, Time to reach 120 AU:  29.53 years
#
# Turning angle:  96.27° | Flyby Speed:  10.13 km/s
#
# Elements for EARTH -> JUPITER → SMA: 553800127.122 km, ECC: 0.7258, INC: 0.24°
#
# Elements EARTH -> JUPITER → RAAN: 124.490° , AP: 175.7325°, TA: 1.22°
#
#
#
# Launch: 2036-Aug-23 00:00:00, Arrival: 2038-Dec-11 00:00:00, C3: 91.55 km²/s², Delta v: 9.57 km/s
#
# Time to reach Jupiter: 2.30 years, Time to 200 AU from Jupiter Flyby:  49.58 years, Total Time to 200 AU from Launch: 51.89 years
#
# Time to reach 90 AU:  21.59 years, Time to reach 120 AU:  29.22 years
#
# Turning angle:  116.02° | Flyby Speed:  12.62 km/s
#
# Elements for EARTH -> JUPITER → SMA: 490229849.905 km, ECC: 0.6914, INC: 5.25°
#
# Elements EARTH -> JUPITER → RAAN: 329.934° , AP: 1.2648°, TA: -0.53°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2049-Oct-14 00:00:00, C3: 82.21 km²/s², Delta v: 9.07 km/s
#
# Time to reach Jupiter: 2.22 years, Time to 200 AU from Jupiter Flyby:  49.72 years, Total Time to 200 AU from Launch: 51.94 years
#
# Time to reach 90 AU:  21.64 years, Time to reach 120 AU:  29.30 years
#
# Turning angle:  115.75° | Flyby Speed:  12.54 km/s
#
# Elements for EARTH -> JUPITER → SMA: 481150267.382 km, ECC: 0.6843, INC: 1.06°
#
# Elements EARTH -> JUPITER → RAAN: 303.011° , AP: 358.5416°, TA: 0.75°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2043-Nov-15 00:00:00, C3: 87.53 km²/s², Delta v: 9.36 km/s
#
# Time to reach Jupiter: 3.95 years, Time to 200 AU from Jupiter Flyby:  48.05 years, Total Time to 200 AU from Launch: 52.00 years
#
# Time to reach 90 AU:  20.92 years, Time to reach 120 AU:  28.32 years
#
# Turning angle:  110.40° | Flyby Speed:  12.60 km/s
#
# Elements for EARTH -> JUPITER → SMA: 492249115.649 km, ECC: 0.7035, INC: 0.01°
#
# Elements EARTH -> JUPITER → RAAN: 223.438° , AP: 222.3178°, TA: -5.28°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2041-Dec-25 00:00:00, C3: 94.49 km²/s², Delta v: 9.72 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  49.98 years, Total Time to 200 AU from Launch: 52.04 years
#
# Time to reach 90 AU:  21.76 years, Time to reach 120 AU:  29.46 years
#
# Turning angle:  104.45° | Flyby Speed:  11.17 km/s
#
# Elements for EARTH -> JUPITER → SMA: 518822436.108 km, ECC: 0.7182, INC: 2.29°
#
# Elements EARTH -> JUPITER → RAAN: 73.283° , AP: 348.3500°, TA: 4.68°
#
#
#
# Launch: 2042-Feb-23 00:00:00, Arrival: 2046-Jan-03 00:00:00, C3: 86.79 km²/s², Delta v: 9.32 km/s
#
# Time to reach Jupiter: 3.86 years, Time to 200 AU from Jupiter Flyby:  48.22 years, Total Time to 200 AU from Launch: 52.08 years
#
# Time to reach 90 AU:  20.99 years, Time to reach 120 AU:  28.41 years
#
# Turning angle:  104.55° | Flyby Speed:  11.86 km/s
#
# Elements for EARTH -> JUPITER → SMA: 480711237.517 km, ECC: 0.6922, INC: 4.93°
#
# Elements EARTH -> JUPITER → RAAN: 153.932° , AP: 357.6956°, TA: 0.97°
#
#
#
# Launch: 2046-Jun-02 00:00:00, Arrival: 2048-Oct-19 00:00:00, C3: 96.06 km²/s², Delta v: 9.80 km/s
#
# Time to reach Jupiter: 2.38 years, Time to 200 AU from Jupiter Flyby:  49.73 years, Total Time to 200 AU from Launch: 52.11 years
#
# Time to reach 90 AU:  21.65 years, Time to reach 120 AU:  29.31 years
#
# Turning angle:  116.83° | Flyby Speed:  12.65 km/s
#
# Elements for EARTH -> JUPITER → SMA: 459677156.642 km, ECC: 0.6746, INC: 2.84°
#
# Elements EARTH -> JUPITER → RAAN: 250.902° , AP: 15.3497°, TA: -6.75°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2049-Jul-16 00:00:00, C3: 79.96 km²/s², Delta v: 8.94 km/s
#
# Time to reach Jupiter: 3.04 years, Time to 200 AU from Jupiter Flyby:  49.08 years, Total Time to 200 AU from Launch: 52.12 years
#
# Time to reach 90 AU:  21.37 years, Time to reach 120 AU:  28.93 years
#
# Turning angle:  116.59° | Flyby Speed:  12.87 km/s
#
# Elements for EARTH -> JUPITER → SMA: 466566219.773 km, ECC: 0.6741, INC: 1.05°
#
# Elements EARTH -> JUPITER → RAAN: 99.985° , AP: 178.1834°, TA: 0.66°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2049-Aug-15 00:00:00, C3: 80.25 km²/s², Delta v: 8.96 km/s
#
# Time to reach Jupiter: 3.12 years, Time to 200 AU from Jupiter Flyby:  49.08 years, Total Time to 200 AU from Launch: 52.21 years
#
# Time to reach 90 AU:  21.37 years, Time to reach 120 AU:  28.93 years
#
# Turning angle:  115.86° | Flyby Speed:  12.79 km/s
#
# Elements for EARTH -> JUPITER → SMA: 468740215.979 km, ECC: 0.6755, INC: 1.16°
#
# Elements EARTH -> JUPITER → RAAN: 99.957° , AP: 179.7367°, TA: -0.01°
#
#
#
# Launch: 2047-Aug-26 00:00:00, Arrival: 2051-Aug-05 00:00:00, C3: 97.23 km²/s², Delta v: 9.86 km/s
#
# Time to reach Jupiter: 3.95 years, Time to 200 AU from Jupiter Flyby:  48.34 years, Total Time to 200 AU from Launch: 52.29 years
#
# Time to reach 90 AU:  21.04 years, Time to reach 120 AU:  28.49 years
#
# Turning angle:  110.17° | Flyby Speed:  12.46 km/s
#
# Elements for EARTH -> JUPITER → SMA: 503751600.920 km, ECC: 0.6999, INC: 6.06°
#
# Elements EARTH -> JUPITER → RAAN: 152.082° , AP: 178.2074°, TA: 0.74°
#
#
#
# Launch: 2043-Mar-20 00:00:00, Arrival: 2045-Sep-05 00:00:00, C3: 95.56 km²/s², Delta v: 9.78 km/s
#
# Time to reach Jupiter: 2.47 years, Time to 200 AU from Jupiter Flyby:  49.96 years, Total Time to 200 AU from Launch: 52.42 years
#
# Time to reach 90 AU:  21.75 years, Time to reach 120 AU:  29.44 years
#
# Turning angle:  115.49° | Flyby Speed:  12.43 km/s
#
# Elements for EARTH -> JUPITER → SMA: 447097679.727 km, ECC: 0.6750, INC: 2.97°
#
# Elements EARTH -> JUPITER → RAAN: 358.682° , AP: 159.9112°, TA: 8.92°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2044-Sep-10 00:00:00, C3: 89.07 km²/s², Delta v: 9.44 km/s
#
# Time to reach Jupiter: 3.70 years, Time to 200 AU from Jupiter Flyby:  49.03 years, Total Time to 200 AU from Launch: 52.72 years
#
# Time to reach 90 AU:  21.34 years, Time to reach 120 AU:  28.89 years
#
# Turning angle:  110.65° | Flyby Speed:  12.24 km/s
#
# Elements for EARTH -> JUPITER → SMA: 478065477.612 km, ECC: 0.6960, INC: 1.21°
#
# Elements EARTH -> JUPITER → RAAN: 98.571° , AP: 13.6690°, TA: -5.91°
#
#
#
# Launch: 2047-Aug-26 00:00:00, Arrival: 2051-Sep-04 00:00:00, C3: 93.47 km²/s², Delta v: 9.67 km/s
#
# Time to reach Jupiter: 4.03 years, Time to 200 AU from Jupiter Flyby:  48.71 years, Total Time to 200 AU from Launch: 52.74 years
#
# Time to reach 90 AU:  21.21 years, Time to reach 120 AU:  28.71 years
#
# Turning angle:  109.59° | Flyby Speed:  12.25 km/s
#
# Elements for EARTH -> JUPITER → SMA: 506784294.009 km, ECC: 0.7016, INC: 5.13°
#
# Elements EARTH -> JUPITER → RAAN: 152.087° , AP: 179.8666°, TA: 0.04°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2038-Dec-11 00:00:00, C3: 87.76 km²/s², Delta v: 9.37 km/s
#
# Time to reach Jupiter: 3.37 years, Time to 200 AU from Jupiter Flyby:  49.40 years, Total Time to 200 AU from Launch: 52.77 years
#
# Time to reach 90 AU:  21.51 years, Time to reach 120 AU:  29.11 years
#
# Turning angle:  116.15° | Flyby Speed:  12.70 km/s
#
# Elements for EARTH -> JUPITER → SMA: 482443693.608 km, ECC: 0.6862, INC: 3.37°
#
# Elements EARTH -> JUPITER → RAAN: 126.280° , AP: 187.1336°, TA: -3.11°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2044-Feb-13 00:00:00, C3: 78.65 km²/s², Delta v: 8.87 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  50.74 years, Total Time to 200 AU from Launch: 52.79 years
#
# Time to reach 90 AU:  22.09 years, Time to reach 120 AU:  29.90 years
#
# Turning angle:  104.65° | Flyby Speed:  10.92 km/s
#
# Elements for EARTH -> JUPITER → SMA: 488383009.883 km, ECC: 0.6985, INC: 0.60°
#
# Elements EARTH -> JUPITER → RAAN: 303.135° , AP: 178.6778°, TA: 0.72°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2050-Dec-08 00:00:00, C3: 93.64 km²/s², Delta v: 9.68 km/s
#
# Time to reach Jupiter: 3.37 years, Time to 200 AU from Jupiter Flyby:  49.54 years, Total Time to 200 AU from Launch: 52.91 years
#
# Time to reach 90 AU:  21.56 years, Time to reach 120 AU:  29.19 years
#
# Turning angle:  116.34° | Flyby Speed:  12.67 km/s
#
# Elements for EARTH -> JUPITER → SMA: 482173637.801 km, ECC: 0.6887, INC: 2.51°
#
# Elements EARTH -> JUPITER → RAAN: 123.392° , AP: 193.9556°, TA: -6.07°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2042-Feb-23 00:00:00, C3: 91.76 km²/s², Delta v: 9.58 km/s
#
# Time to reach Jupiter: 2.22 years, Time to 200 AU from Jupiter Flyby:  50.77 years, Total Time to 200 AU from Launch: 52.99 years
#
# Time to reach 90 AU:  22.10 years, Time to reach 120 AU:  29.92 years
#
# Turning angle:  110.63° | Flyby Speed:  11.60 km/s
#
# Elements for EARTH -> JUPITER → SMA: 498180206.180 km, ECC: 0.7064, INC: 2.56°
#
# Elements EARTH -> JUPITER → RAAN: 73.269° , AP: 348.7194°, TA: 4.64°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2045-Jul-07 00:00:00, C3: 95.08 km²/s², Delta v: 9.75 km/s
#
# Time to reach Jupiter: 3.45 years, Time to 200 AU from Jupiter Flyby:  49.54 years, Total Time to 200 AU from Launch: 53.00 years
#
# Time to reach 90 AU:  21.57 years, Time to reach 120 AU:  29.20 years
#
# Turning angle:  110.78° | Flyby Speed:  12.06 km/s
#
# Elements for EARTH -> JUPITER → SMA: 464786681.432 km, ECC: 0.6886, INC: 2.15°
#
# Elements EARTH -> JUPITER → RAAN: 123.645° , AP: 16.5391°, TA: -7.19°
#
#
#
# Launch: 2043-Mar-20 00:00:00, Arrival: 2047-Jan-28 00:00:00, C3: 88.82 km²/s², Delta v: 9.42 km/s
#
# Time to reach Jupiter: 3.86 years, Time to 200 AU from Jupiter Flyby:  49.33 years, Total Time to 200 AU from Launch: 53.19 years
#
# Time to reach 90 AU:  21.47 years, Time to reach 120 AU:  29.07 years
#
# Turning angle:  102.64° | Flyby Speed:  11.20 km/s
#
# Elements for EARTH -> JUPITER → SMA: 478890987.238 km, ECC: 0.6904, INC: 3.01°
#
# Elements EARTH -> JUPITER → RAAN: 178.675° , AP: 8.4905°, TA: -3.64°
#
#
#
# Launch: 2046-Jun-02 00:00:00, Arrival: 2048-Sep-19 00:00:00, C3: 98.90 km²/s², Delta v: 9.94 km/s
#
# Time to reach Jupiter: 2.30 years, Time to 200 AU from Jupiter Flyby:  50.89 years, Total Time to 200 AU from Launch: 53.19 years
#
# Time to reach 90 AU:  22.15 years, Time to reach 120 AU:  29.99 years
#
# Turning angle:  115.44° | Flyby Speed:  12.08 km/s
#
# Elements for EARTH -> JUPITER → SMA: 462011668.339 km, ECC: 0.6758, INC: 4.45°
#
# Elements EARTH -> JUPITER → RAAN: 250.944° , AP: 14.4526°, TA: -6.35°
#
#
#
# Launch: 2038-Nov-11 00:00:00, Arrival: 2042-Jun-23 00:00:00, C3: 86.68 km²/s², Delta v: 9.31 km/s
#
# Time to reach Jupiter: 3.62 years, Time to 200 AU from Jupiter Flyby:  49.64 years, Total Time to 200 AU from Launch: 53.26 years
#
# Time to reach 90 AU:  21.61 years, Time to reach 120 AU:  29.26 years
#
# Turning angle:  116.13° | Flyby Speed:  12.61 km/s
#
# Elements for EARTH -> JUPITER → SMA: 490204934.349 km, ECC: 0.6978, INC: 4.37°
#
# Elements EARTH -> JUPITER → RAAN: 228.104° , AP: 181.3826°, TA: -0.56°
#
#
#
# Launch: 2045-Jun-07 00:00:00, Arrival: 2048-Oct-19 00:00:00, C3: 94.86 km²/s², Delta v: 9.74 km/s
#
# Time to reach Jupiter: 3.37 years, Time to 200 AU from Jupiter Flyby:  49.98 years, Total Time to 200 AU from Launch: 53.35 years
#
# Time to reach 90 AU:  21.76 years, Time to reach 120 AU:  29.46 years
#
# Turning angle:  109.09° | Flyby Speed:  11.71 km/s
#
# Elements for EARTH -> JUPITER → SMA: 469370562.389 km, ECC: 0.6774, INC: 6.28°
#
# Elements EARTH -> JUPITER → RAAN: 255.992° , AP: 353.7295°, TA: 2.78°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2043-Jun-18 00:00:00, C3: 79.25 km²/s², Delta v: 8.90 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  49.87 years, Total Time to 200 AU from Launch: 53.41 years
#
# Time to reach 90 AU:  21.71 years, Time to reach 120 AU:  29.39 years
#
# Turning angle:  115.79° | Flyby Speed:  12.49 km/s
#
# Elements for EARTH -> JUPITER → SMA: 481580852.590 km, ECC: 0.6943, INC: 1.10°
#
# Elements EARTH -> JUPITER → RAAN: 252.877° , AP: 184.9175°, TA: -1.97°
#
#
#
# Launch: 2045-Jun-07 00:00:00, Arrival: 2048-Mar-23 00:00:00, C3: 96.84 km²/s², Delta v: 9.84 km/s
#
# Time to reach Jupiter: 2.79 years, Time to 200 AU from Jupiter Flyby:  50.73 years, Total Time to 200 AU from Launch: 53.53 years
#
# Time to reach 90 AU:  22.09 years, Time to reach 120 AU:  29.90 years
#
# Turning angle:  115.42° | Flyby Speed:  12.13 km/s
#
# Elements for EARTH -> JUPITER → SMA: 451825787.563 km, ECC: 0.6707, INC: 3.27°
#
# Elements EARTH -> JUPITER → RAAN: 76.145° , AP: 161.7061°, TA: 8.13°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2043-Dec-15 00:00:00, C3: 90.49 km²/s², Delta v: 9.51 km/s
#
# Time to reach Jupiter: 4.03 years, Time to 200 AU from Jupiter Flyby:  49.54 years, Total Time to 200 AU from Launch: 53.56 years
#
# Time to reach 90 AU:  21.56 years, Time to reach 120 AU:  29.19 years
#
# Turning angle:  109.22° | Flyby Speed:  11.89 km/s
#
# Elements for EARTH -> JUPITER → SMA: 494660956.878 km, ECC: 0.7058, INC: 0.11°
#
# Elements EARTH -> JUPITER → RAAN: 76.000° , AP: 11.4788°, TA: -5.98°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2043-May-19 00:00:00, C3: 78.96 km²/s², Delta v: 8.89 km/s
#
# Time to reach Jupiter: 3.45 years, Time to 200 AU from Jupiter Flyby:  50.17 years, Total Time to 200 AU from Launch: 53.62 years
#
# Time to reach 90 AU:  21.84 years, Time to reach 120 AU:  29.57 years
#
# Turning angle:  116.69° | Flyby Speed:  12.48 km/s
#
# Elements for EARTH -> JUPITER → SMA: 479813010.266 km, ECC: 0.6929, INC: 1.56°
#
# Elements EARTH -> JUPITER → RAAN: 252.958° , AP: 183.3829°, TA: -1.36°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2049-Jun-16 00:00:00, C3: 86.76 km²/s², Delta v: 9.31 km/s
#
# Time to reach Jupiter: 1.89 years, Time to 200 AU from Jupiter Flyby:  51.75 years, Total Time to 200 AU from Launch: 53.64 years
#
# Time to reach 90 AU:  22.53 years, Time to reach 120 AU:  30.50 years
#
# Turning angle:  104.74° | Flyby Speed:  10.57 km/s
#
# Elements for EARTH -> JUPITER → SMA: 515319191.081 km, ECC: 0.7053, INC: 0.02°
#
# Elements EARTH -> JUPITER → RAAN: 285.008° , AP: 15.0692°, TA: 1.33°
#
#
#
# Launch: 2043-Mar-20 00:00:00, Arrival: 2045-Dec-04 00:00:00, C3: 94.80 km²/s², Delta v: 9.74 km/s
#
# Time to reach Jupiter: 2.71 years, Time to 200 AU from Jupiter Flyby:  51.00 years, Total Time to 200 AU from Launch: 53.71 years
#
# Time to reach 90 AU:  22.20 years, Time to reach 120 AU:  30.06 years
#
# Turning angle:  115.36° | Flyby Speed:  12.03 km/s
#
# Elements for EARTH -> JUPITER → SMA: 447127040.095 km, ECC: 0.6723, INC: 5.08°
#
# Elements EARTH -> JUPITER → RAAN: 358.681° , AP: 163.5994°, TA: 7.30°
#
#
#
# Launch: 2049-Oct-14 00:00:00, Arrival: 2053-Jun-25 00:00:00, C3: 89.19 km²/s², Delta v: 9.44 km/s
#
# Time to reach Jupiter: 3.70 years, Time to 200 AU from Jupiter Flyby:  50.39 years, Total Time to 200 AU from Launch: 54.09 years
#
# Time to reach 90 AU:  21.94 years, Time to reach 120 AU:  29.70 years
#
# Turning angle:  115.95° | Flyby Speed:  12.32 km/s
#
# Elements for EARTH -> JUPITER → SMA: 495869722.939 km, ECC: 0.6995, INC: 4.55°
#
# Elements EARTH -> JUPITER → RAAN: 200.360° , AP: 184.9783°, TA: -2.08°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2037-Jul-19 00:00:00, C3: 91.30 km²/s², Delta v: 9.55 km/s
#
# Time to reach Jupiter: 1.97 years, Time to 200 AU from Jupiter Flyby:  52.15 years, Total Time to 200 AU from Launch: 54.12 years
#
# Time to reach 90 AU:  22.70 years, Time to reach 120 AU:  30.73 years
#
# Turning angle:  108.94° | Flyby Speed:  10.92 km/s
#
# Elements for EARTH -> JUPITER → SMA: 497671601.016 km, ECC: 0.6969, INC: 0.06°
#
# Elements EARTH -> JUPITER → RAAN: 130.093° , AP: 165.4791°, TA: 4.51°
#
#
#
# Launch: 2038-Nov-11 00:00:00, Arrival: 2042-May-24 00:00:00, C3: 91.58 km²/s², Delta v: 9.57 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  50.68 years, Total Time to 200 AU from Launch: 54.21 years
#
# Time to reach 90 AU:  22.06 years, Time to reach 120 AU:  29.86 years
#
# Turning angle:  116.64° | Flyby Speed:  12.29 km/s
#
# Elements for EARTH -> JUPITER → SMA: 488284266.179 km, ECC: 0.6966, INC: 5.74°
#
# Elements EARTH -> JUPITER → RAAN: 228.116° , AP: 179.9621°, TA: 0.03°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2042-May-24 00:00:00, C3: 88.89 km²/s², Delta v: 9.43 km/s
#
# Time to reach Jupiter: 2.47 years, Time to 200 AU from Jupiter Flyby:  51.78 years, Total Time to 200 AU from Launch: 54.25 years
#
# Time to reach 90 AU:  22.54 years, Time to reach 120 AU:  30.52 years
#
# Turning angle:  116.83° | Flyby Speed:  11.92 km/s
#
# Elements for EARTH -> JUPITER → SMA: 481639514.596 km, ECC: 0.6957, INC: 3.22°
#
# Elements EARTH -> JUPITER → RAAN: 73.245° , AP: 350.1611°, TA: 4.14°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2050-Feb-11 00:00:00, C3: 88.21 km²/s², Delta v: 9.39 km/s
#
# Time to reach Jupiter: 3.62 years, Time to 200 AU from Jupiter Flyby:  50.84 years, Total Time to 200 AU from Launch: 54.46 years
#
# Time to reach 90 AU:  22.13 years, Time to reach 120 AU:  29.96 years
#
# Turning angle:  110.75° | Flyby Speed:  11.58 km/s
#
# Elements for EARTH -> JUPITER → SMA: 484506271.491 km, ECC: 0.6880, INC: 1.26°
#
# Elements EARTH -> JUPITER → RAAN: 99.934° , AP: 189.6043°, TA: -4.25°
#
#
#
# Launch: 2049-Oct-14 00:00:00, Arrival: 2053-May-26 00:00:00, C3: 91.72 km²/s², Delta v: 9.58 km/s
#
# Time to reach Jupiter: 3.62 years, Time to 200 AU from Jupiter Flyby:  50.89 years, Total Time to 200 AU from Launch: 54.51 years
#
# Time to reach 90 AU:  22.15 years, Time to reach 120 AU:  29.99 years
#
# Turning angle:  116.61° | Flyby Speed:  12.21 km/s
#
# Elements for EARTH -> JUPITER → SMA: 493757038.911 km, ECC: 0.6980, INC: 5.44°
#
# Elements EARTH -> JUPITER → RAAN: 200.365° , AP: 183.5498°, TA: -1.48°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2043-Nov-15 00:00:00, C3: 84.29 km²/s², Delta v: 9.18 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  52.74 years, Total Time to 200 AU from Launch: 54.54 years
#
# Time to reach 90 AU:  22.96 years, Time to reach 120 AU:  31.08 years
#
# Turning angle:  92.42° | Flyby Speed:  8.71 km/s
#
# Elements for EARTH -> JUPITER → SMA: 538329541.558 km, ECC: 0.7265, INC: 0.01°
#
# Elements EARTH -> JUPITER → RAAN: 141.806° , AP: 340.2847°, TA: 0.57°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2048-Oct-19 00:00:00, C3: 88.15 km²/s², Delta v: 9.39 km/s
#
# Time to reach Jupiter: 2.30 years, Time to 200 AU from Jupiter Flyby:  52.56 years, Total Time to 200 AU from Launch: 54.86 years
#
# Time to reach 90 AU:  22.88 years, Time to reach 120 AU:  30.97 years
#
# Turning angle:  117.16° | Flyby Speed:  11.69 km/s
#
# Elements for EARTH -> JUPITER → SMA: 461052461.984 km, ECC: 0.6734, INC: 1.35°
#
# Elements EARTH -> JUPITER → RAAN: 99.918° , AP: 166.9051°, TA: 5.70°
#
#
#
# Launch: 2036-Aug-23 00:00:00, Arrival: 2040-Mar-05 00:00:00, C3: 99.24 km²/s², Delta v: 9.96 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  51.35 years, Total Time to 200 AU from Launch: 54.88 years
#
# Time to reach 90 AU:  22.35 years, Time to reach 120 AU:  30.26 years
#
# Turning angle:  116.71° | Flyby Speed:  12.05 km/s
#
# Elements for EARTH -> JUPITER → SMA: 490260156.328 km, ECC: 0.6972, INC: 2.93°
#
# Elements EARTH -> JUPITER → RAAN: 149.996° , AP: 197.3940°, TA: -7.41°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2044-Dec-09 00:00:00, C3: 82.94 km²/s², Delta v: 9.11 km/s
#
# Time to reach Jupiter: 2.88 years, Time to 200 AU from Jupiter Flyby:  52.05 years, Total Time to 200 AU from Launch: 54.93 years
#
# Time to reach 90 AU:  22.66 years, Time to reach 120 AU:  30.68 years
#
# Turning angle:  117.11° | Flyby Speed:  11.86 km/s
#
# Elements for EARTH -> JUPITER → SMA: 454970577.421 km, ECC: 0.6771, INC: 4.17°
#
# Elements EARTH -> JUPITER → RAAN: 123.591° , AP: 5.9940°, TA: -2.66°
#
#
#
# Launch: 2049-Oct-14 00:00:00, Arrival: 2052-Feb-01 00:00:00, C3: 99.43 km²/s², Delta v: 9.97 km/s
#
# Time to reach Jupiter: 2.30 years, Time to 200 AU from Jupiter Flyby:  52.67 years, Total Time to 200 AU from Launch: 54.97 years
#
# Time to reach 90 AU:  22.93 years, Time to reach 120 AU:  31.04 years
#
# Turning angle:  115.53° | Flyby Speed:  11.48 km/s
#
# Elements for EARTH -> JUPITER → SMA: 496462036.636 km, ECC: 0.7027, INC: 3.15°
#
# Elements EARTH -> JUPITER → RAAN: 20.446° , AP: 346.7232°, TA: 5.55°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2038-Nov-11 00:00:00, C3: 87.60 km²/s², Delta v: 9.36 km/s
#
# Time to reach Jupiter: 3.29 years, Time to 200 AU from Jupiter Flyby:  51.88 years, Total Time to 200 AU from Launch: 55.16 years
#
# Time to reach 90 AU:  22.58 years, Time to reach 120 AU:  30.57 years
#
# Turning angle:  116.89° | Flyby Speed:  11.89 km/s
#
# Elements for EARTH -> JUPITER → SMA: 480188378.876 km, ECC: 0.6843, INC: 3.81°
#
# Elements EARTH -> JUPITER → RAAN: 126.272° , AP: 185.6643°, TA: -2.48°
#
#
#
# Launch: 2045-Jun-07 00:00:00, Arrival: 2048-Nov-18 00:00:00, C3: 84.86 km²/s², Delta v: 9.21 km/s
#
# ...
#
# Turning angle:  117.83° | Flyby Speed:  8.50 km/s
#
# Elements for EARTH -> JUPITER → SMA: 462816438.709 km, ECC: 0.6718, INC: 1.86°
#
# Elements EARTH -> JUPITER → RAAN: 99.851° , AP: 175.3929°, TA: 1.96°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2044-Feb-13 00:00:00, C3: 76.38 km²/s², Delta v: 8.74 km/s
#
# Time to reach Jupiter: 3.12 years, Time to 200 AU from Jupiter Flyby:  64.76 years, Total Time to 200 AU from Launch: 67.89 years
#
# Time to reach 90 AU:  28.19 years, Time to reach 120 AU:  38.17 years
#
# Turning angle:  117.83° | Flyby Speed:  8.45 km/s
#
# Elements for EARTH -> JUPITER → SMA: 466016578.703 km, ECC: 0.6845, INC: 1.02°
#
# Elements EARTH -> JUPITER → RAAN: 98.616° , AP: 2.8678°, TA: -1.37°
#
#
#
# Launch: 2039-Dec-06 00:00:00, Arrival: 2043-Oct-16 00:00:00, C3: 85.02 km²/s², Delta v: 9.22 km/s
#
# Time to reach Jupiter: 3.86 years, Time to 200 AU from Jupiter Flyby:  64.34 years, Total Time to 200 AU from Launch: 68.21 years
#
# Time to reach 90 AU:  28.01 years, Time to reach 120 AU:  37.92 years
#
# Turning angle:  111.56° | Flyby Speed:  7.86 km/s
#
# Elements for EARTH -> JUPITER → SMA: 489916073.467 km, ECC: 0.7013, INC: 0.15°
#
# Elements EARTH -> JUPITER → RAAN: 251.072° , AP: 193.0027°, TA: -4.59°
#
#
#
# Launch: 2045-Jun-07 00:00:00, Arrival: 2048-Dec-18 00:00:00, C3: 82.38 km²/s², Delta v: 9.08 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  65.14 years, Total Time to 200 AU from Launch: 68.67 years
#
# Time to reach 90 AU:  28.36 years, Time to reach 120 AU:  38.39 years
#
# Turning angle:  108.26° | Flyby Speed:  7.31 km/s
#
# Elements for EARTH -> JUPITER → SMA: 475476696.251 km, ECC: 0.6808, INC: 2.09°
#
# Elements EARTH -> JUPITER → RAAN: 255.886° , AP: 357.4900°, TA: 1.16°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2048-Apr-22 00:00:00, C3: 90.26 km²/s², Delta v: 9.50 km/s
#
# Time to reach Jupiter: 2.96 years, Time to 200 AU from Jupiter Flyby:  65.75 years, Total Time to 200 AU from Launch: 68.71 years
#
# Time to reach 90 AU:  28.62 years, Time to reach 120 AU:  38.75 years
#
# Turning angle:  114.53° | Flyby Speed:  7.88 km/s
#
# Elements for EARTH -> JUPITER → SMA: 454315927.696 km, ECC: 0.6706, INC: 2.60°
#
# Elements EARTH -> JUPITER → RAAN: 227.090° , AP: 12.0815°, TA: -5.33°
#
#
#
# Launch: 2043-Feb-18 00:00:00, Arrival: 2044-Nov-09 00:00:00, C3: 90.28 km²/s², Delta v: 9.50 km/s
#
# Time to reach Jupiter: 1.73 years, Time to 200 AU from Jupiter Flyby:  67.05 years, Total Time to 200 AU from Launch: 68.78 years
#
# Time to reach 90 AU:  29.19 years, Time to reach 120 AU:  39.52 years
#
# Turning angle:  89.23° | Flyby Speed:  4.54 km/s
#
# Elements for EARTH -> JUPITER → SMA: 539747495.713 km, ECC: 0.7267, INC: 2.13°
#
# Elements EARTH -> JUPITER → RAAN: 328.544° , AP: 185.8559°, TA: -2.30°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2049-Jul-16 00:00:00, C3: 85.17 km²/s², Delta v: 9.23 km/s
#
# Time to reach Jupiter: 1.97 years, Time to 200 AU from Jupiter Flyby:  67.01 years, Total Time to 200 AU from Launch: 68.98 years
#
# Time to reach 90 AU:  29.17 years, Time to reach 120 AU:  39.49 years
#
# Turning angle:  108.22° | Flyby Speed:  6.91 km/s
#
# Elements for EARTH -> JUPITER → SMA: 502941540.335 km, ECC: 0.6981, INC: 0.18°
#
# Elements EARTH -> JUPITER → RAAN: 301.726° , AP: 358.5196°, TA: 1.28°
#
#
#
# Launch: 2038-Nov-11 00:00:00, Arrival: 2041-Apr-29 00:00:00, C3: 99.25 km²/s², Delta v: 9.96 km/s
#
# Time to reach Jupiter: 2.47 years, Time to 200 AU from Jupiter Flyby:  66.71 years, Total Time to 200 AU from Launch: 69.17 years
#
# Time to reach 90 AU:  29.04 years, Time to reach 120 AU:  39.31 years
#
# Turning angle:  117.79° | Flyby Speed:  8.03 km/s
#
# Elements for EARTH -> JUPITER → SMA: 487301217.846 km, ECC: 0.6998, INC: 3.49°
#
# Elements EARTH -> JUPITER → RAAN: 48.218° , AP: 345.8294°, TA: 5.95°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2047-Nov-24 00:00:00, C3: 96.04 km²/s², Delta v: 9.80 km/s
#
# Time to reach Jupiter: 3.62 years, Time to 200 AU from Jupiter Flyby:  65.81 years, Total Time to 200 AU from Launch: 69.43 years
#
# Time to reach 90 AU:  28.65 years, Time to reach 120 AU:  38.78 years
#
# Turning angle:  105.45° | Flyby Speed:  6.85 km/s
#
# Elements for EARTH -> JUPITER → SMA: 470697050.257 km, ECC: 0.6853, INC: 2.12°
#
# Elements EARTH -> JUPITER → RAAN: 203.028° , AP: 14.2582°, TA: -6.15°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2050-Jan-12 00:00:00, C3: 86.02 km²/s², Delta v: 9.27 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  66.95 years, Total Time to 200 AU from Launch: 70.48 years
#
# Time to reach 90 AU:  29.14 years, Time to reach 120 AU:  39.45 years
#
# Turning angle:  111.64° | Flyby Speed:  7.31 km/s
#
# Elements for EARTH -> JUPITER → SMA: 481638860.875 km, ECC: 0.6855, INC: 1.26°
#
# Elements EARTH -> JUPITER → RAAN: 99.935° , AP: 187.8916°, TA: -3.53°
#
#
#
# Launch: 2042-Feb-23 00:00:00, Arrival: 2045-Dec-04 00:00:00, C3: 90.71 km²/s², Delta v: 9.52 km/s
#
# Time to reach Jupiter: 3.78 years, Time to 200 AU from Jupiter Flyby:  66.98 years, Total Time to 200 AU from Launch: 70.77 years
#
# Time to reach 90 AU:  29.16 years, Time to reach 120 AU:  39.48 years
#
# Turning angle:  105.49° | Flyby Speed:  6.60 km/s
#
# Elements for EARTH -> JUPITER → SMA: 477816490.487 km, ECC: 0.6906, INC: 5.95°
#
# Elements EARTH -> JUPITER → RAAN: 153.928° , AP: 355.7406°, TA: 1.81°
#
#
#
# Launch: 2043-Feb-18 00:00:00, Arrival: 2046-Feb-02 00:00:00, C3: 95.96 km²/s², Delta v: 9.80 km/s
#
# Time to reach Jupiter: 2.96 years, Time to 200 AU from Jupiter Flyby:  68.00 years, Total Time to 200 AU from Launch: 70.96 years
#
# Time to reach 90 AU:  29.60 years, Time to reach 120 AU:  40.07 years
#
# Turning angle:  114.43° | Flyby Speed:  7.41 km/s
#
# Elements for EARTH -> JUPITER → SMA: 448954295.890 km, ECC: 0.6760, INC: 3.26°
#
# Elements EARTH -> JUPITER → RAAN: 148.665° , AP: 16.1951°, TA: -7.18°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2051-Feb-06 00:00:00, C3: 98.99 km²/s², Delta v: 9.95 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  67.51 years, Total Time to 200 AU from Launch: 71.04 years
#
# Time to reach 90 AU:  29.39 years, Time to reach 120 AU:  39.78 years
#
# Turning angle:  114.60° | Flyby Speed:  7.52 km/s
#
# Elements for EARTH -> JUPITER → SMA: 486810780.752 km, ECC: 0.6935, INC: 2.25°
#
# Elements EARTH -> JUPITER → RAAN: 123.406° , AP: 196.9531°, TA: -7.31°
#
#
#
# Launch: 2046-Jul-02 00:00:00, Arrival: 2048-Nov-18 00:00:00, C3: 86.62 km²/s², Delta v: 9.31 km/s
#
# Time to reach Jupiter: 2.38 years, Time to 200 AU from Jupiter Flyby:  68.69 years, Total Time to 200 AU from Launch: 71.07 years
#
# Time to reach 90 AU:  29.90 years, Time to reach 120 AU:  40.48 years
#
# Turning angle:  118.01° | Flyby Speed:  7.65 km/s
#
# Elements for EARTH -> JUPITER → SMA: 459619094.710 km, ECC: 0.6719, INC: 1.35°
#
# Elements EARTH -> JUPITER → RAAN: 99.917° , AP: 167.8866°, TA: 5.27°
#
#
#
# Launch: 2042-Feb-23 00:00:00, Arrival: 2045-Mar-09 00:00:00, C3: 99.50 km²/s², Delta v: 9.98 km/s
#
# Time to reach Jupiter: 3.04 years, Time to 200 AU from Jupiter Flyby:  68.65 years, Total Time to 200 AU from Launch: 71.69 years
#
# Time to reach 90 AU:  29.88 years, Time to reach 120 AU:  40.46 years
#
# Turning angle:  114.44° | Flyby Speed:  7.28 km/s
#
# Elements for EARTH -> JUPITER → SMA: 456525415.903 km, ECC: 0.6838, INC: 3.85°
#
# Elements EARTH -> JUPITER → RAAN: 333.882° , AP: 159.9849°, TA: 8.76°
#
#
#
# Launch: 2047-Jul-27 00:00:00, Arrival: 2050-Oct-09 00:00:00, C3: 89.95 km²/s², Delta v: 9.48 km/s
#
# Time to reach Jupiter: 3.21 years, Time to 200 AU from Jupiter Flyby:  68.75 years, Total Time to 200 AU from Launch: 71.96 years
#
# Time to reach 90 AU:  29.93 years, Time to reach 120 AU:  40.52 years
#
# Turning angle:  117.91° | Flyby Speed:  7.63 km/s
#
# Elements for EARTH -> JUPITER → SMA: 478054301.352 km, ECC: 0.6846, INC: 2.92°
#
# Elements EARTH -> JUPITER → RAAN: 123.377° , AP: 191.0969°, TA: -4.86°
#
#
#
# Launch: 2037-Sep-17 00:00:00, Arrival: 2040-Oct-31 00:00:00, C3: 98.05 km²/s², Delta v: 9.90 km/s
#
# Time to reach Jupiter: 3.12 years, Time to 200 AU from Jupiter Flyby:  68.96 years, Total Time to 200 AU from Launch: 72.08 years
#
# Time to reach 90 AU:  30.02 years, Time to reach 120 AU:  40.64 years
#
# Turning angle:  120.91° | Flyby Speed:  7.91 km/s
#
# Elements for EARTH -> JUPITER → SMA: 482912685.433 km, ECC: 0.6941, INC: 3.86°
#
# Elements EARTH -> JUPITER → RAAN: 173.941° , AP: 196.8446°, TA: -7.20°
#
#
#
# Launch: 2046-Jun-02 00:00:00, Arrival: 2048-Dec-18 00:00:00, C3: 97.48 km²/s², Delta v: 9.87 km/s
#
# Time to reach Jupiter: 2.55 years, Time to 200 AU from Jupiter Flyby:  69.61 years, Total Time to 200 AU from Launch: 72.15 years
#
# Time to reach 90 AU:  30.30 years, Time to reach 120 AU:  41.02 years
#
# Turning angle:  118.04° | Flyby Speed:  7.48 km/s
#
# Elements for EARTH -> JUPITER → SMA: 457434865.212 km, ECC: 0.6744, INC: 1.37°
#
# Elements EARTH -> JUPITER → RAAN: 250.777° , AP: 17.4765°, TA: -7.65°
#
#
#
# Launch: 2042-Jan-24 00:00:00, Arrival: 2043-Aug-17 00:00:00, C3: 95.73 km²/s², Delta v: 9.78 km/s
#
# Time to reach Jupiter: 1.56 years, Time to 200 AU from Jupiter Flyby:  70.82 years, Total Time to 200 AU from Launch: 72.38 years
#
# Time to reach 90 AU:  30.83 years, Time to reach 120 AU:  41.73 years
#
# Turning angle:  76.53° | Flyby Speed:  1.92 km/s
#
# Elements for EARTH -> JUPITER → SMA: 666759730.949 km, ECC: 0.7791, INC: 0.34°
#
# Elements EARTH -> JUPITER → RAAN: 124.244° , AP: 359.8046°, TA: -0.18°
#
#
#
# Launch: 2038-Nov-11 00:00:00, Arrival: 2042-Nov-20 00:00:00, C3: 85.26 km²/s², Delta v: 9.23 km/s
#
# Time to reach Jupiter: 4.03 years, Time to 200 AU from Jupiter Flyby:  68.45 years, Total Time to 200 AU from Launch: 72.48 years
#
# Time to reach 90 AU:  29.80 years, Time to reach 120 AU:  40.34 years
#
# Turning angle:  111.66° | Flyby Speed:  7.01 km/s
#
# Elements for EARTH -> JUPITER → SMA: 501344638.464 km, ECC: 0.7060, INC: 1.63°
#
# Elements EARTH -> JUPITER → RAAN: 228.018° , AP: 189.1158°, TA: -3.73°
#
#
#
# Launch: 2038-Nov-11 00:00:00, Arrival: 2042-Aug-22 00:00:00, C3: 83.53 km²/s², Delta v: 9.14 km/s
#
# Time to reach Jupiter: 3.78 years, Time to 200 AU from Jupiter Flyby:  68.74 years, Total Time to 200 AU from Launch: 72.52 years
#
# Time to reach 90 AU:  29.92 years, Time to reach 120 AU:  40.51 years
#
# Turning angle:  114.55° | Flyby Speed:  7.27 km/s
#
# Elements for EARTH -> JUPITER → SMA: 494389899.006 km, ECC: 0.7007, INC: 2.81°
#
# Elements EARTH -> JUPITER → RAAN: 228.075° , AP: 184.3550°, TA: -1.79°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2046-Aug-01 00:00:00, C3: 87.38 km²/s², Delta v: 9.35 km/s
#
# Time to reach Jupiter: 2.30 years, Time to 200 AU from Jupiter Flyby:  70.42 years, Total Time to 200 AU from Launch: 72.72 years
#
# Time to reach 90 AU:  30.65 years, Time to reach 120 AU:  41.50 years
#
# Turning angle:  114.34° | Flyby Speed:  6.93 km/s
#
# Elements for EARTH -> JUPITER → SMA: 447977763.390 km, ECC: 0.6676, INC: 4.72°
#
# Elements EARTH -> JUPITER → RAAN: 23.138° , AP: 168.9796°, TA: 4.92°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2039-Feb-09 00:00:00, C3: 89.96 km²/s², Delta v: 9.48 km/s
#
# Time to reach Jupiter: 3.53 years, Time to 200 AU from Jupiter Flyby:  69.57 years, Total Time to 200 AU from Launch: 73.10 years
#
# Time to reach 90 AU:  30.29 years, Time to reach 120 AU:  41.00 years
#
# Turning angle:  114.52° | Flyby Speed:  7.11 km/s
#
# Elements for EARTH -> JUPITER → SMA: 487300466.418 km, ECC: 0.6903, INC: 2.80°
#
# Elements EARTH -> JUPITER → RAAN: 126.293° , AP: 190.1684°, TA: -4.39°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2037-Aug-18 00:00:00, C3: 89.64 km²/s², Delta v: 9.47 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  71.07 years, Total Time to 200 AU from Launch: 73.12 years
#
# Time to reach 90 AU:  30.94 years, Time to reach 120 AU:  41.88 years
#
# Turning angle:  111.80° | Flyby Speed:  6.53 km/s
#
# Elements for EARTH -> JUPITER → SMA: 489159564.798 km, ECC: 0.6915, INC: 0.08°
#
# Elements EARTH -> JUPITER → RAAN: 303.500° , AP: 352.4437°, TA: 4.40°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2048-Jul-21 00:00:00, C3: 98.73 km²/s², Delta v: 9.94 km/s
#
# Time to reach Jupiter: 3.21 years, Time to 200 AU from Jupiter Flyby:  69.96 years, Total Time to 200 AU from Launch: 73.17 years
#
# Time to reach 90 AU:  30.46 years, Time to reach 120 AU:  41.23 years
#
# Turning angle:  111.81° | Flyby Speed:  6.74 km/s
#
# Elements for EARTH -> JUPITER → SMA: 460641666.130 km, ECC: 0.6780, INC: 1.45°
#
# Elements EARTH -> JUPITER → RAAN: 227.008° , AP: 17.0640°, TA: -7.44°
#
#
#
# Launch: 2044-Apr-13 00:00:00, Arrival: 2046-Feb-02 00:00:00, C3: 91.32 km²/s², Delta v: 9.56 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  71.37 years, Total Time to 200 AU from Launch: 73.18 years
#
# Time to reach 90 AU:  31.07 years, Time to reach 120 AU:  42.06 years
#
# Turning angle:  99.35° | Flyby Speed:  5.02 km/s
#
# Elements for EARTH -> JUPITER → SMA: 489269985.109 km, ECC: 0.6972, INC: 2.29°
#
# Elements EARTH -> JUPITER → RAAN: 23.174° , AP: 165.8069°, TA: 5.99°
#
#
#
# Launch: 2045-May-08 00:00:00, Arrival: 2047-Jun-27 00:00:00, C3: 93.60 km²/s², Delta v: 9.67 km/s
#
# Time to reach Jupiter: 2.14 years, Time to 200 AU from Jupiter Flyby:  71.15 years, Total Time to 200 AU from Launch: 73.29 years
#
# Time to reach 90 AU:  30.97 years, Time to reach 120 AU:  41.93 years
#
# Turning angle:  111.87° | Flyby Speed:  6.52 km/s
#
# Elements for EARTH -> JUPITER → SMA: 458656090.121 km, ECC: 0.6708, INC: 6.74°
#
# Elements EARTH -> JUPITER → RAAN: 47.233° , AP: 180.0141°, TA: -0.02°
#
#
#
# Launch: 2040-Jan-05 00:00:00, Arrival: 2044-Jan-14 00:00:00, C3: 98.44 km²/s², Delta v: 9.92 km/s
#
# Time to reach Jupiter: 4.03 years, Time to 200 AU from Jupiter Flyby:  69.28 years, Total Time to 200 AU from Launch: 73.31 years
#
# Time to reach 90 AU:  30.16 years, Time to reach 120 AU:  40.83 years
#
# Turning angle:  108.16° | Flyby Speed:  6.45 km/s
#
# Elements for EARTH -> JUPITER → SMA: 496411257.031 km, ECC: 0.7075, INC: 4.18°
#
# Elements EARTH -> JUPITER → RAAN: 103.753° , AP: 345.6478°, TA: 5.94°
#
#
#
# Launch: 2040-Dec-30 00:00:00, Arrival: 2044-Nov-09 00:00:00, C3: 96.52 km²/s², Delta v: 9.82 km/s
#
# Time to reach Jupiter: 3.86 years, Time to 200 AU from Jupiter Flyby:  69.52 years, Total Time to 200 AU from Launch: 73.38 years
#
# Time to reach 90 AU:  30.26 years, Time to reach 120 AU:  40.97 years
#
# Turning angle:  108.11° | Flyby Speed:  6.40 km/s
#
# Elements for EARTH -> JUPITER → SMA: 482741808.175 km, ECC: 0.7010, INC: 1.23°
#
# Elements EARTH -> JUPITER → RAAN: 98.567° , AP: 17.2218°, TA: -7.37°
#
#
#
# Launch: 2048-Aug-20 00:00:00, Arrival: 2050-Sep-09 00:00:00, C3: 94.99 km²/s², Delta v: 9.75 km/s
#
# Time to reach Jupiter: 2.05 years, Time to 200 AU from Jupiter Flyby:  71.51 years, Total Time to 200 AU from Launch: 73.56 years
#
# Time to reach 90 AU:  31.13 years, Time to reach 120 AU:  42.14 years
#
# Turning angle:  108.14° | Flyby Speed:  6.04 km/s
#
# Elements for EARTH -> JUPITER → SMA: 515443118.105 km, ECC: 0.7073, INC: 4.65°
#
# Elements EARTH -> JUPITER → RAAN: 326.956° , AP: 7.2648°, TA: -3.00°
#
#
#
# Launch: 2035-Jul-30 00:00:00, Arrival: 2037-May-20 00:00:00, C3: 95.16 km²/s², Delta v: 9.76 km/s
#
# Time to reach Jupiter: 1.81 years, Time to 200 AU from Jupiter Flyby:  72.22 years, Total Time to 200 AU from Launch: 74.03 years
#
# Time to reach 90 AU:  31.44 years, Time to reach 120 AU:  42.56 years
#
# Turning angle:  101.75° | Flyby Speed:  5.16 km/s
#
# Elements for EARTH -> JUPITER → SMA: 523953064.325 km, ECC: 0.7123, INC: 0.26°
#
# Elements EARTH -> JUPITER → RAAN: 127.024° , AP: 168.2455°, TA: 4.50°
#
#
#
# Launch: 2046-Jun-02 00:00:00, Arrival: 2049-Jan-17 00:00:00, C3: 99.52 km²/s², Delta v: 9.98 km/s
#
# Time to reach Jupiter: 2.63 years, Time to 200 AU from Jupiter Flyby:  72.34 years, Total Time to 200 AU from Launch: 74.97 years
#
# Time to reach 90 AU:  31.49 years, Time to reach 120 AU:  42.63 years
#
# Turning angle:  118.12° | Flyby Speed:  6.99 km/s
#
# Elements for EARTH -> JUPITER → SMA: 457253059.964 km, ECC: 0.6750, INC: 0.97°
#
# Elements EARTH -> JUPITER → RAAN: 250.678° , AP: 18.7043°, TA: -8.15°

# %%
def ecliptic_to_cartesian(lambda_deg, beta_deg, distance_km):
    lam_rad = np.deg2rad(lambda_deg)
    beta_rad = np.deg2rad(beta_deg)

    x = distance_km * np.cos(beta_rad) * np.cos(lam_rad) #cos(lat)cos(long)
    y = distance_km * np.cos(beta_rad) * np.sin(lam_rad)
    z = distance_km * np.sin(beta_rad)
    return np.array([x, y, z])


lam_deg = 240 # Latitude of the Nose from Freeman's
beta_deg = 7.5 # Longitude of the Nose from Freeman's
heliopause_distance = 120*pk.AU 

rH = ecliptic_to_cartesian(lam_deg, beta_deg, heliopause_distance) # position of the nose of the helioshpere
#print("Cartesian position (heliocentric, J2000):", rH)

# Set launch window
start_date = pk.epoch_from_string("2039-01-01 00:00:00")
end_date = pk.epoch_from_string("2046-01-01 00:00:00")

# Parameters
launch_step = 30     # days between launch trials
tof_range = (12000, 24000)  # in days, time of flight range

# %%
# Results list
results = []

# Scan through departure dates
t_dep = start_date
while t_dep.mjd2000 < end_date.mjd2000:
    rJ, vJ = jupiter.eph(t_dep)
    
    for tof_days in range(tof_range[0], tof_range[1], 30):  # try multiple TOFs
        try:
            t_arr = pk.epoch(t_dep.mjd2000 + tof_days)
            dt_sec = tof_days * pk.DAY2SEC
            l2 = pk.lambert_problem(r1=rJ, r2=rH, tof=dt_sec, mu=pk.MU_SUN, max_revs=2)

            v1 = np.array(l2.get_v1()[0])
            v2 = np.array(l2.get_v2()[0])
            v_inf = (v1 - np.array(vJ))/1000
            C3 = np.linalg.norm(v_inf) ** 2  # in km²/s²
            if C3 <= 250:
                # Get Keplerian elements of transfer orbit
                kep = pk.ic2par(rJ, v1, pk.MU_SUN)  # r, v at arrival → orbital elements

                results.append({
                    'departure': str(t_dep),
                    'arrival': str(t_arr),
                    'tof_days': tof_days,
                    'C3': C3,
                    'sma': kep[0],   # semi-major axis
                    'ecc': kep[1],   # eccentricity
                    'inc': np.degrees(kep[2]),  # inclination (rad → deg)
                    'raan': np.degrees(kep[3]),
                    'argp': np.degrees(kep[4]),
                    'ta': np.degrees(kep[5]),
                })

        except RuntimeError as e:
            # Lambert solver may fail for some configurations; skip them
            continue

    t_dep = pk.epoch(t_dep.mjd2000 + launch_step)

# %%
#Sort by C3 (ascending)
results.sort(key=lambda x: x['tof_days'])

# Print trajectories
for res in results[:]:
    print(f"Launch: {res['departure']}, Arrival: {res['arrival']}, C3: {res['C3']:.2f} km²/s², Time to reach Nose: {res['tof_days']/365: .2f} years\n")
    print(f"Elements for JUPITER -> HELIOPAUSE → SMA: {res['sma']/1000:.3f} km, ECC: {res['ecc']:.4f}, INC: {res['inc']:.2f}°\n")
    print(f"Elements JUPITER -> HELIOPAUSE → RAAN: {res['raan']:.3f}° , AP: {res['argp']:.4f}°, TA: {res['ta']:.2f}°\n\n\n")
# Out:
# Launch: 2039-Jan-01 00:00:00, Arrival: 2071-Nov-09 00:00:00, C3: 141.14 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 519006723.889 km, ECC: 2.5166, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 354.2819°, TA: 8.03°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2071-Dec-09 00:00:00, C3: 143.42 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 520711299.829 km, ECC: 2.5030, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 352.1452°, TA: 9.65°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Jan-08 00:00:00, C3: 146.34 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 522445119.075 km, ECC: 2.4872, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.9722°, TA: 11.27°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Feb-07 00:00:00, C3: 149.90 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 524205204.980 km, ECC: 2.4693, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.7600°, TA: 12.90°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Mar-08 00:00:00, C3: 154.09 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 525988466.338 km, ECC: 2.4492, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 345.5057°, TA: 14.54°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Apr-07 00:00:00, C3: 158.91 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 527791711.645 km, ECC: 2.4270, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 343.2062°, TA: 16.17°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-May-07 00:00:00, C3: 164.38 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 529611653.940 km, ECC: 2.4027, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.8586°, TA: 17.81°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 170.48 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 531444917.604 km, ECC: 2.3764, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 338.4597°, TA: 19.45°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 177.21 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 533288053.943 km, ECC: 2.3480, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 336.0064°, TA: 21.10°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 184.58 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 535137538.256 km, ECC: 2.3178, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 333.4953°, TA: 22.74°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 192.58 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 536989767.913 km, ECC: 2.2856, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.9231°, TA: 24.39°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 201.21 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 538841070.136 km, ECC: 2.2515, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 328.2863°, TA: 26.03°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 210.46 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 540687698.713 km, ECC: 2.2157, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 325.5813°, TA: 27.67°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 220.34 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 542525842.635 km, ECC: 2.1782, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.8044°, TA: 29.31°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 230.83 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 544351646.092 km, ECC: 2.1390, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.9519°, TA: 30.94°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 241.92 km²/s², Time to reach Nose:  32.88 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 546161213.607 km, ECC: 2.0983, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 317.0198°, TA: 32.57°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2071-Dec-09 00:00:00, C3: 140.48 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 522032745.348 km, ECC: 2.5075, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 354.1971°, TA: 8.07°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Jan-08 00:00:00, C3: 142.79 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 523747626.988 km, ECC: 2.4939, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 352.0594°, TA: 9.69°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Feb-07 00:00:00, C3: 145.72 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 525491937.737 km, ECC: 2.4781, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.8854°, TA: 11.31°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Mar-08 00:00:00, C3: 149.28 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 527262683.825 km, ECC: 2.4602, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.6720°, TA: 12.94°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Apr-07 00:00:00, C3: 153.48 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 529056756.116 km, ECC: 2.4402, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 345.4165°, TA: 14.57°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-May-07 00:00:00, C3: 158.32 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 530870944.462 km, ECC: 2.4181, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 343.1158°, TA: 16.20°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 163.79 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 532701942.560 km, ECC: 2.3939, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.7669°, TA: 17.84°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 169.89 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 534546354.795 km, ECC: 2.3677, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 338.3667°, TA: 19.48°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 176.63 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 536400711.913 km, ECC: 2.3395, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.9120°, TA: 21.12°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 184.00 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 538261468.089 km, ECC: 2.3093, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 333.3994°, TA: 22.76°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 192.00 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 540124998.969 km, ECC: 2.2773, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.8256°, TA: 24.40°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 200.62 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 541987609.519 km, ECC: 2.2434, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 328.1872°, TA: 26.04°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 209.87 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 543845530.706 km, ECC: 2.2077, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 325.4804°, TA: 27.68°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 219.74 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 545694928.183 km, ECC: 2.1704, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.7018°, TA: 29.32°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 230.22 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 547531922.414 km, ECC: 2.1314, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.8474°, TA: 30.95°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 241.31 km²/s², Time to reach Nose:  32.96 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 549352593.841 km, ECC: 2.0909, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.9134°, TA: 32.58°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Jan-08 00:00:00, C3: 139.84 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 525070886.597 km, ECC: 2.4985, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 354.1123°, TA: 8.11°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Feb-07 00:00:00, C3: 142.16 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 526796123.794 km, ECC: 2.4849, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.9736°, TA: 9.73°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Mar-08 00:00:00, C3: 145.10 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 528550976.809 km, ECC: 2.4692, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.7985°, TA: 11.35°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Apr-07 00:00:00, C3: 148.67 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 530332434.669 km, ECC: 2.4513, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.5841°, TA: 12.97°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-May-07 00:00:00, C3: 152.88 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 532137370.233 km, ECC: 2.4313, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 345.3274°, TA: 14.60°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 157.72 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 533962554.621 km, ECC: 2.4093, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 343.0254°, TA: 16.23°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 163.20 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 535804662.106 km, ECC: 2.3852, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.6752°, TA: 17.87°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 169.31 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 537660276.982 km, ECC: 2.3590, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 338.2736°, TA: 19.51°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 176.05 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 539525909.346 km, ECC: 2.3309, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.8175°, TA: 21.14°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 183.42 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 541397992.145 km, ECC: 2.3009, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 333.3034°, TA: 22.78°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 191.42 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 543272879.206 km, ECC: 2.2690, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.7281°, TA: 24.42°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 200.04 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 545146853.132 km, ECC: 2.2353, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 328.0880°, TA: 26.06°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 209.29 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 547016121.963 km, ECC: 2.1998, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 325.3795°, TA: 27.70°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 219.15 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 548876827.903 km, ECC: 2.1627, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.5991°, TA: 29.33°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 229.62 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 550725067.575 km, ECC: 2.1239, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.7429°, TA: 30.96°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 240.70 km²/s², Time to reach Nose:  33.04 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 552556897.227 km, ECC: 2.0836, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.8070°, TA: 32.58°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Feb-07 00:00:00, C3: 139.20 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 528121187.632 km, ECC: 2.4895, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 354.0275°, TA: 8.16°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Mar-08 00:00:00, C3: 141.53 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 529856830.506 km, ECC: 2.4759, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.8878°, TA: 9.77°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Apr-07 00:00:00, C3: 144.49 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 531622276.816 km, ECC: 2.4602, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.7116°, TA: 11.39°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-May-07 00:00:00, C3: 148.07 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 533414498.311 km, ECC: 2.4424, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.4960°, TA: 13.01°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 152.29 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 535230349.763 km, ECC: 2.4225, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 345.2382°, TA: 14.64°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 157.14 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 537066583.477 km, ECC: 2.4005, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.9350°, TA: 16.27°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 162.62 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 538919854.215 km, ECC: 2.3765, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.5835°, TA: 17.90°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 168.74 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 540786726.089 km, ECC: 2.3505, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 338.1806°, TA: 19.53°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 175.48 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 542663688.451 km, ECC: 2.3225, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.7230°, TA: 21.17°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 182.85 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 544547152.924 km, ECC: 2.2926, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 333.2074°, TA: 22.80°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 190.85 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 546433451.415 km, ECC: 2.2608, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.6305°, TA: 24.44°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 199.47 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 548318844.058 km, ECC: 2.2273, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 327.9888°, TA: 26.07°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 208.71 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 550199515.858 km, ECC: 2.1920, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 325.2787°, TA: 27.71°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 218.57 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 552071585.461 km, ECC: 2.1550, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.4965°, TA: 29.34°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 229.03 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 553931125.533 km, ECC: 2.1164, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.6384°, TA: 30.96°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 240.10 km²/s², Time to reach Nose:  33.12 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 555774168.011 km, ECC: 2.0763, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.7006°, TA: 32.59°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Mar-08 00:00:00, C3: 138.57 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 531183688.648 km, ECC: 2.4806, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 353.9426°, TA: 8.20°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Apr-07 00:00:00, C3: 140.91 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 532929787.584 km, ECC: 2.4670, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.8019°, TA: 9.81°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-May-07 00:00:00, C3: 143.88 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 534705878.487 km, ECC: 2.4514, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.6247°, TA: 11.42°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 147.48 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 536508915.752 km, ECC: 2.4336, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.4080°, TA: 13.04°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 151.70 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 538335735.985 km, ECC: 2.4138, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 345.1490°, TA: 14.67°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 156.56 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 540183072.592 km, ECC: 2.3918, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.8446°, TA: 16.30°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 162.05 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 542047560.733 km, ECC: 2.3679, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.4918°, TA: 17.93°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 168.17 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 543925744.250 km, ECC: 2.3420, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 338.0875°, TA: 19.56°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 174.91 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 545814091.652 km, ECC: 2.3141, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.6284°, TA: 21.19°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 182.28 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 547708993.141 km, ECC: 2.2843, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 333.1114°, TA: 22.82°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 190.28 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 549606758.603 km, ECC: 2.2527, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.5329°, TA: 24.46°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 198.90 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 551503625.598 km, ECC: 2.2193, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 327.8896°, TA: 26.09°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 208.14 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 553395755.987 km, ECC: 2.1842, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 325.1778°, TA: 27.72°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 217.99 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 555279244.746 km, ECC: 2.1473, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.3938°, TA: 29.35°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 228.45 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 557150140.469 km, ECC: 2.1090, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.5339°, TA: 30.97°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Jun-01 00:00:00, C3: 239.51 km²/s², Time to reach Nose:  33.21 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 559004450.665 km, ECC: 2.0691, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.5942°, TA: 32.59°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Apr-07 00:00:00, C3: 137.94 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 534258430.040 km, ECC: 2.4718, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 353.8578°, TA: 8.24°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-May-07 00:00:00, C3: 140.30 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 536015035.688 km, ECC: 2.4582, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.7161°, TA: 9.85°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 143.28 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 537801822.752 km, ECC: 2.4426, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.5377°, TA: 11.46°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 146.89 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 539615728.199 km, ECC: 2.4249, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.3199°, TA: 13.08°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 151.12 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 541453570.385 km, ECC: 2.4051, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 345.0597°, TA: 14.70°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 155.99 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 543312063.734 km, ECC: 2.3832, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.7541°, TA: 16.33°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 161.48 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 545187823.715 km, ECC: 2.3594, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.4000°, TA: 17.95°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 167.60 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 547077373.808 km, ECC: 2.3336, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 337.9944°, TA: 19.58°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 174.35 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 548977161.585 km, ECC: 2.3058, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.5339°, TA: 21.21°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 181.73 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 550883555.728 km, ECC: 2.2761, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 333.0154°, TA: 22.84°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 189.72 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 552792843.997 km, ECC: 2.2447, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.4354°, TA: 24.48°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 198.34 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 554701241.274 km, ECC: 2.2114, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 327.7904°, TA: 26.11°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 207.57 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 556604886.168 km, ECC: 2.1764, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 325.0769°, TA: 27.73°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 217.42 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 558499849.871 km, ECC: 2.1398, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.2912°, TA: 29.36°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Jun-01 00:00:00, C3: 227.87 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 560382156.791 km, ECC: 2.1016, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.4294°, TA: 30.98°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Jul-01 00:00:00, C3: 238.92 km²/s², Time to reach Nose:  33.29 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 562247789.891 km, ECC: 2.0619, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.4878°, TA: 32.60°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-May-07 00:00:00, C3: 137.32 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 537345452.403 km, ECC: 2.4630, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 353.7729°, TA: 8.28°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 139.69 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 539112615.680 km, ECC: 2.4495, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.6302°, TA: 9.89°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 142.68 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 540910150.748 km, ECC: 2.4339, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.4508°, TA: 11.50°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 146.30 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 542734977.064 km, ECC: 2.4162, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.2319°, TA: 13.11°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 150.55 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 544583894.657 km, ECC: 2.3965, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 344.9705°, TA: 14.73°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 155.42 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 546453598.883 km, ECC: 2.3747, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.6636°, TA: 16.36°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 160.92 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 548340685.431 km, ECC: 2.3509, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.3082°, TA: 17.98°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 167.05 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 550241657.325 km, ECC: 2.3252, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 337.9012°, TA: 19.61°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 173.80 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 552152941.105 km, ECC: 2.2975, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.4394°, TA: 21.24°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 181.17 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 554070883.833 km, ECC: 2.2680, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 332.9193°, TA: 22.86°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 189.17 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 555991751.042 km, ECC: 2.2367, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.3378°, TA: 24.49°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 197.78 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 557911734.829 km, ECC: 2.2036, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 327.6912°, TA: 26.12°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 207.01 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 559826950.442 km, ECC: 2.1687, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 324.9760°, TA: 27.75°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Jun-01 00:00:00, C3: 216.85 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 561733445.174 km, ECC: 2.1323, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.1885°, TA: 29.37°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Jul-01 00:00:00, C3: 227.30 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 563627219.134 km, ECC: 2.0943, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.3250°, TA: 30.99°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Jul-31 00:00:00, C3: 238.34 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 565504230.619 km, ECC: 2.0548, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.3814°, TA: 32.60°
#
#
#
# Launch: 2040-Apr-25 00:00:00, Arrival: 2073-Aug-30 00:00:00, C3: 249.97 km²/s², Time to reach Nose:  33.37 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 567360407.028 km, ECC: 2.0139, INC: 7.98°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 170.173° , AP: 313.3539°, TA: 34.21°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Jun-06 00:00:00, C3: 136.71 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 540444796.533 km, ECC: 2.4543, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 353.6880°, TA: 8.32°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 139.09 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 542222568.626 km, ECC: 2.4408, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.5442°, TA: 9.93°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 142.10 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 544030903.814 km, ECC: 2.4252, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.3638°, TA: 11.53°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 145.72 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 545866703.967 km, ECC: 2.4076, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.1438°, TA: 13.15°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 149.98 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 547726750.705 km, ECC: 2.3879, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 344.8812°, TA: 14.76°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 154.86 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 549607720.228 km, ECC: 2.3662, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.5731°, TA: 16.39°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 160.37 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 551506188.359 km, ECC: 2.3425, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.2164°, TA: 18.01°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 166.50 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 553418637.573 km, ECC: 2.3169, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 337.8081°, TA: 19.63°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 173.25 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 555341473.280 km, ECC: 2.2894, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.3448°, TA: 21.26°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 180.62 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 557271020.823 km, ECC: 2.2600, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 332.8233°, TA: 22.88°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 188.62 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 559203523.405 km, ECC: 2.2287, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.2402°, TA: 24.51°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 197.23 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 561135150.230 km, ECC: 2.1958, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 327.5920°, TA: 26.14°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-Jun-01 00:00:00, C3: 206.46 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 563061993.075 km, ECC: 2.1611, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 324.8751°, TA: 27.76°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Jul-01 00:00:00, C3: 216.29 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 564980075.222 km, ECC: 2.1248, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 322.0859°, TA: 29.38°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Jul-31 00:00:00, C3: 226.73 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 566885372.363 km, ECC: 2.0870, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.2205°, TA: 30.99°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Aug-30 00:00:00, C3: 237.76 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 568773818.010 km, ECC: 2.0477, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.2751°, TA: 32.60°
#
#
#
# Launch: 2040-Apr-25 00:00:00, Arrival: 2073-Sep-29 00:00:00, C3: 249.38 km²/s², Time to reach Nose:  33.45 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 570641314.478 km, ECC: 2.0070, INC: 7.98°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 170.173° , AP: 313.2456°, TA: 34.21°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Jul-06 00:00:00, C3: 136.10 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 543556503.431 km, ECC: 2.4456, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 353.6030°, TA: 8.36°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 138.50 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 545344935.798 km, ECC: 2.4322, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.4583°, TA: 9.96°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 141.51 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 547164123.497 km, ECC: 2.4166, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.2768°, TA: 11.57°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 145.15 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 549010950.736 km, ECC: 2.3990, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 347.0556°, TA: 13.18°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 149.42 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 550882180.640 km, ECC: 2.3794, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 344.7919°, TA: 14.80°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 154.30 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 552774470.172 km, ECC: 2.3578, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.4826°, TA: 16.41°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 159.82 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 554684375.196 km, ECC: 2.3342, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.1246°, TA: 18.04°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 165.95 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 556608357.542 km, ECC: 2.3087, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 337.7149°, TA: 19.66°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 172.71 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 558542801.398 km, ECC: 2.2812, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.2502°, TA: 21.28°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 180.08 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 560484010.286 km, ECC: 2.2520, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 332.7272°, TA: 22.90°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 188.08 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 562428204.973 km, ECC: 2.2209, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.1426°, TA: 24.53°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2073-Jun-01 00:00:00, C3: 196.68 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 564371531.667 km, ECC: 2.1881, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 327.4928°, TA: 26.15°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-Jul-01 00:00:00, C3: 205.91 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 566310058.559 km, ECC: 2.1536, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 324.7742°, TA: 27.77°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Jul-31 00:00:00, C3: 215.74 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 568239784.809 km, ECC: 2.1175, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 321.9832°, TA: 29.39°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Aug-30 00:00:00, C3: 226.17 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 570156661.571 km, ECC: 2.0798, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.1161°, TA: 31.00°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Sep-29 00:00:00, C3: 237.19 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 572056597.457 km, ECC: 2.0407, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.1688°, TA: 32.61°
#
#
#
# Launch: 2040-Apr-25 00:00:00, Arrival: 2073-Oct-29 00:00:00, C3: 248.80 km²/s², Time to reach Nose:  33.53 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 573935469.573 km, ECC: 2.0003, INC: 7.98°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 170.173° , AP: 313.1374°, TA: 34.21°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Aug-05 00:00:00, C3: 135.50 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 546680614.299 km, ECC: 2.4371, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 353.5181°, TA: 8.40°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 137.91 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 548479758.672 km, ECC: 2.4236, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.3723°, TA: 10.00°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 140.94 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 550309851.553 km, ECC: 2.4081, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.1898°, TA: 11.61°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 144.59 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 552167759.409 km, ECC: 2.3905, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 346.9675°, TA: 13.22°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 148.86 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 554050226.789 km, ECC: 2.3710, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 344.7026°, TA: 14.83°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 153.75 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 555953891.331 km, ECC: 2.3494, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.3920°, TA: 16.44°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 159.27 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 557875288.850 km, ECC: 2.3259, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 340.0328°, TA: 18.06°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 165.41 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 559810860.440 km, ECC: 2.3005, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 337.6217°, TA: 19.68°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 172.17 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 561756968.966 km, ECC: 2.2732, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 335.1556°, TA: 21.30°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 179.55 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 563709896.029 km, ECC: 2.2440, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 332.6312°, TA: 22.92°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2073-Jun-01 00:00:00, C3: 187.54 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 565665839.859 km, ECC: 2.2131, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 330.0450°, TA: 24.54°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2073-Jul-01 00:00:00, C3: 196.14 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 567620923.554 km, ECC: 2.1804, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 327.3935°, TA: 26.16°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2073-Jul-31 00:00:00, C3: 205.36 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 569571191.613 km, ECC: 2.1461, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 324.6733°, TA: 27.78°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2073-Aug-30 00:00:00, C3: 215.19 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 571512618.956 km, ECC: 2.1101, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 321.8806°, TA: 29.40°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2073-Sep-29 00:00:00, C3: 225.61 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 573441132.086 km, ECC: 2.0727, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 319.0116°, TA: 31.01°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2073-Oct-29 00:00:00, C3: 236.62 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 575352614.588 km, ECC: 2.0338, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 316.0625°, TA: 32.61°
#
#
#
# Launch: 2040-Apr-25 00:00:00, Arrival: 2073-Nov-28 00:00:00, C3: 248.22 km²/s², Time to reach Nose:  33.62 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 577242918.241 km, ECC: 1.9935, INC: 7.98°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 170.173° , AP: 313.0292°, TA: 34.21°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2072-Sep-04 00:00:00, C3: 134.90 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 549817170.548 km, ECC: 2.4285, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 353.4331°, TA: 8.44°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2072-Oct-04 00:00:00, C3: 137.33 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 551627078.933 km, ECC: 2.4151, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 351.2864°, TA: 10.04°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2072-Nov-03 00:00:00, C3: 140.37 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 553468129.945 km, ECC: 2.3996, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 349.1027°, TA: 11.64°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2072-Dec-03 00:00:00, C3: 144.03 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 555337172.233 km, ECC: 2.3821, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 346.8793°, TA: 13.25°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2073-Jan-02 00:00:00, C3: 148.31 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 557230931.688 km, ECC: 2.3626, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 344.6132°, TA: 14.86°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2073-Feb-01 00:00:00, C3: 153.21 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 559146026.534 km, ECC: 2.3411, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 342.3015°, TA: 16.47°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2073-Mar-03 00:00:00, C3: 158.73 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 561078972.448 km, ECC: 2.3177, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 339.9409°, TA: 18.09°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2073-Apr-02 00:00:00, C3: 164.88 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 563026189.693 km, ECC: 2.2924, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 337.5285°, TA: 19.71°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2073-May-02 00:00:00, C3: 171.64 km²/s², Time to reach Nose:  33.70 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 564984019.712 km, ECC: 2.2652, INC: 7.51°
#
# ...
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 295.4265°, TA: 21.49°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2105-Jun-14 00:00:00, C3: 156.73 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3674837167.271 km, ECC: 1.1307, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 292.5319°, TA: 22.17°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2105-Jul-14 00:00:00, C3: 165.38 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3693166901.400 km, ECC: 1.1244, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 289.5820°, TA: 22.84°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2105-Aug-13 00:00:00, C3: 174.35 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3711439136.929 km, ECC: 1.1181, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 286.5757°, TA: 23.49°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2105-Sep-12 00:00:00, C3: 183.62 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3729614691.691 km, ECC: 1.1118, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 283.5122°, TA: 24.13°
#
#
#
# Launch: 2040-Apr-25 00:00:00, Arrival: 2105-Oct-12 00:00:00, C3: 193.20 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3747653475.224 km, ECC: 1.1055, INC: 7.98°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 170.173° , AP: 280.3910°, TA: 24.75°
#
#
#
# Launch: 2040-May-25 00:00:00, Arrival: 2105-Nov-11 00:00:00, C3: 203.07 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3765514633.018 km, ECC: 1.0992, INC: 8.11°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 172.530° , AP: 277.2119°, TA: 25.35°
#
#
#
# Launch: 2040-Jun-24 00:00:00, Arrival: 2105-Dec-11 00:00:00, C3: 213.25 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3783156534.403 km, ECC: 1.0930, INC: 8.26°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 174.921° , AP: 273.9747°, TA: 25.94°
#
#
#
# Launch: 2040-Jul-24 00:00:00, Arrival: 2106-Jan-10 00:00:00, C3: 223.72 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3800536842.366 km, ECC: 1.0868, INC: 8.43°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 177.343° , AP: 270.6798°, TA: 26.51°
#
#
#
# Launch: 2040-Aug-23 00:00:00, Arrival: 2106-Feb-09 00:00:00, C3: 234.47 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3817612692.263 km, ECC: 1.0807, INC: 8.63°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 179.798° , AP: 267.3278°, TA: 27.06°
#
#
#
# Launch: 2040-Sep-22 00:00:00, Arrival: 2106-Mar-11 00:00:00, C3: 245.51 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3834340787.607 km, ECC: 1.0748, INC: 8.85°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 182.285° , AP: 263.9198°, TA: 27.59°
#
#
#
# Launch: 2045-Dec-25 00:00:00, Arrival: 2111-Jun-13 00:00:00, C3: 246.70 km²/s², Time to reach Nose:  65.51 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3361309283.820 km, ECC: 1.0863, INC: 7.58°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.178° , AP: 289.0764°, TA: -27.23°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2104-Jul-19 00:00:00, C3: 78.18 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3478752820.055 km, ECC: 1.1971, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 323.9890°, TA: 13.28°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2104-Aug-18 00:00:00, C3: 82.91 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3495239569.327 km, ECC: 1.1924, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 321.5965°, TA: 14.07°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2104-Sep-17 00:00:00, C3: 87.97 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3512049248.446 km, ECC: 1.1875, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 319.1683°, TA: 14.85°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2104-Oct-17 00:00:00, C3: 93.36 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3529157258.324 km, ECC: 1.1824, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 316.7022°, TA: 15.62°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2104-Nov-16 00:00:00, C3: 99.09 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3546537579.186 km, ECC: 1.1771, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 314.1961°, TA: 16.39°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2104-Dec-16 00:00:00, C3: 105.16 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3564162863.430 km, ECC: 1.1716, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 311.6478°, TA: 17.14°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2105-Jan-15 00:00:00, C3: 111.55 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3582004448.449 km, ECC: 1.1660, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 309.0554°, TA: 17.89°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2105-Feb-14 00:00:00, C3: 118.27 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3600032364.848 km, ECC: 1.1603, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 306.4170°, TA: 18.63°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2105-Mar-16 00:00:00, C3: 125.32 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3618215475.771 km, ECC: 1.1544, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 303.7308°, TA: 19.35°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2105-Apr-15 00:00:00, C3: 132.69 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3636521437.685 km, ECC: 1.1484, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 300.9948°, TA: 20.07°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2105-May-15 00:00:00, C3: 140.39 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3654916628.808 km, ECC: 1.1424, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 298.2077°, TA: 20.77°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2105-Jun-14 00:00:00, C3: 148.41 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3673366205.609 km, ECC: 1.1362, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 295.3677°, TA: 21.46°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2105-Jul-14 00:00:00, C3: 156.74 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3691834046.090 km, ECC: 1.1300, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 292.4736°, TA: 22.14°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2105-Aug-13 00:00:00, C3: 165.39 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3710282775.068 km, ECC: 1.1237, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 289.5242°, TA: 22.81°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2105-Sep-12 00:00:00, C3: 174.36 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3728673955.539 km, ECC: 1.1175, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 286.5185°, TA: 23.46°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2105-Oct-12 00:00:00, C3: 183.63 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3746968148.781 km, ECC: 1.1112, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 283.4557°, TA: 24.09°
#
#
#
# Launch: 2040-Apr-25 00:00:00, Arrival: 2105-Nov-11 00:00:00, C3: 193.20 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3765124998.964 km, ECC: 1.1049, INC: 7.98°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 170.173° , AP: 280.3353°, TA: 24.71°
#
#
#
# Launch: 2040-May-25 00:00:00, Arrival: 2105-Dec-11 00:00:00, C3: 203.08 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3783103378.330 km, ECC: 1.0987, INC: 8.11°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 172.530° , AP: 277.1570°, TA: 25.31°
#
#
#
# Launch: 2040-Jun-24 00:00:00, Arrival: 2106-Jan-10 00:00:00, C3: 213.25 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3800861375.021 km, ECC: 1.0925, INC: 8.26°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 174.921° , AP: 273.9208°, TA: 25.90°
#
#
#
# Launch: 2040-Jul-24 00:00:00, Arrival: 2106-Feb-09 00:00:00, C3: 223.71 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3818356363.291 km, ECC: 1.0863, INC: 8.43°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 177.343° , AP: 270.6269°, TA: 26.47°
#
#
#
# Launch: 2040-Aug-23 00:00:00, Arrival: 2106-Mar-11 00:00:00, C3: 234.46 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3835545183.431 km, ECC: 1.0803, INC: 8.63°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 179.798° , AP: 267.2761°, TA: 27.02°
#
#
#
# Launch: 2040-Sep-22 00:00:00, Arrival: 2106-Apr-10 00:00:00, C3: 245.50 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3852384238.257 km, ECC: 1.0744, INC: 8.85°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 182.285° , AP: 263.8693°, TA: 27.55°
#
#
#
# Launch: 2045-Dec-25 00:00:00, Arrival: 2111-Jul-13 00:00:00, C3: 246.41 km²/s², Time to reach Nose:  65.59 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3376407294.981 km, ECC: 1.0860, INC: 7.58°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.178° , AP: 289.0474°, TA: -27.17°
#
#
#
# Launch: 2039-Jan-01 00:00:00, Arrival: 2104-Aug-18 00:00:00, C3: 78.19 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3494475673.202 km, ECC: 1.1961, INC: 7.73°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 135.957° , AP: 323.9289°, TA: 13.28°
#
#
#
# Launch: 2039-Jan-31 00:00:00, Arrival: 2104-Sep-17 00:00:00, C3: 82.92 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3511066407.260 km, ECC: 1.1914, INC: 7.67°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 137.964° , AP: 321.5363°, TA: 14.06°
#
#
#
# Launch: 2039-Mar-02 00:00:00, Arrival: 2104-Oct-17 00:00:00, C3: 87.98 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3527982342.199 km, ECC: 1.1866, INC: 7.61°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 139.981° , AP: 319.1081°, TA: 14.84°
#
#
#
# Launch: 2039-Apr-01 00:00:00, Arrival: 2104-Nov-16 00:00:00, C3: 93.37 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3545198741.014 km, ECC: 1.1815, INC: 7.57°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 142.008° , AP: 316.6419°, TA: 15.61°
#
#
#
# Launch: 2039-May-01 00:00:00, Arrival: 2104-Dec-16 00:00:00, C3: 99.11 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3562689435.788 km, ECC: 1.1762, INC: 7.54°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 144.047° , AP: 314.1358°, TA: 16.37°
#
#
#
# Launch: 2039-May-31 00:00:00, Arrival: 2105-Jan-15 00:00:00, C3: 105.17 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3580426920.927 km, ECC: 1.1708, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 146.102° , AP: 311.5876°, TA: 17.12°
#
#
#
# Launch: 2039-Jun-30 00:00:00, Arrival: 2105-Feb-14 00:00:00, C3: 111.57 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3598382365.883 km, ECC: 1.1652, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 148.173° , AP: 308.9953°, TA: 17.87°
#
#
#
# Launch: 2039-Jul-30 00:00:00, Arrival: 2105-Mar-16 00:00:00, C3: 118.29 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3616525623.180 km, ECC: 1.1595, INC: 7.50°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 150.263° , AP: 306.3571°, TA: 18.61°
#
#
#
# Launch: 2039-Aug-29 00:00:00, Arrival: 2105-Apr-15 00:00:00, C3: 125.34 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3634825368.487 km, ECC: 1.1536, INC: 7.51°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 152.373° , AP: 303.6710°, TA: 19.33°
#
#
#
# Launch: 2039-Sep-28 00:00:00, Arrival: 2105-May-15 00:00:00, C3: 132.71 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3653249061.022 km, ECC: 1.1477, INC: 7.52°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 154.505° , AP: 300.9354°, TA: 20.04°
#
#
#
# Launch: 2039-Oct-28 00:00:00, Arrival: 2105-Jun-14 00:00:00, C3: 140.40 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3671762871.294 km, ECC: 1.1416, INC: 7.55°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 156.661° , AP: 298.1485°, TA: 20.74°
#
#
#
# Launch: 2039-Nov-27 00:00:00, Arrival: 2105-Jul-14 00:00:00, C3: 148.42 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3690331737.822 km, ECC: 1.1355, INC: 7.59°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.842° , AP: 295.3090°, TA: 21.43°
#
#
#
# Launch: 2039-Dec-27 00:00:00, Arrival: 2105-Aug-13 00:00:00, C3: 156.76 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3708919309.893 km, ECC: 1.1293, INC: 7.64°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 161.050° , AP: 292.4153°, TA: 22.11°
#
#
#
# Launch: 2040-Jan-26 00:00:00, Arrival: 2105-Sep-12 00:00:00, C3: 165.41 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3727487972.787 km, ECC: 1.1231, INC: 7.70°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 163.286° , AP: 289.4665°, TA: 22.77°
#
#
#
# Launch: 2040-Feb-25 00:00:00, Arrival: 2105-Oct-12 00:00:00, C3: 174.37 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3745999040.263 km, ECC: 1.1168, INC: 7.78°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 165.551° , AP: 286.4614°, TA: 23.42°
#
#
#
# Launch: 2040-Mar-26 00:00:00, Arrival: 2105-Nov-11 00:00:00, C3: 183.64 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3764412815.004 km, ECC: 1.1106, INC: 7.87°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 167.846° , AP: 283.3993°, TA: 24.05°
#
#
#
# Launch: 2040-Apr-25 00:00:00, Arrival: 2105-Dec-11 00:00:00, C3: 193.21 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3782688673.661 km, ECC: 1.1043, INC: 7.98°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 170.173° , AP: 280.2797°, TA: 24.67°
#
#
#
# Launch: 2040-May-25 00:00:00, Arrival: 2106-Jan-10 00:00:00, C3: 203.08 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3800785212.990 km, ECC: 1.0981, INC: 8.11°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 172.530° , AP: 277.1023°, TA: 25.27°
#
#
#
# Launch: 2040-Jun-24 00:00:00, Arrival: 2106-Feb-09 00:00:00, C3: 213.25 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3818660237.615 km, ECC: 1.0920, INC: 8.26°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 174.921° , AP: 273.8670°, TA: 25.86°
#
#
#
# Launch: 2040-Jul-24 00:00:00, Arrival: 2106-Mar-11 00:00:00, C3: 223.71 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3836270830.631 km, ECC: 1.0859, INC: 8.43°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 177.343° , AP: 270.5742°, TA: 26.42°
#
#
#
# Launch: 2040-Aug-23 00:00:00, Arrival: 2106-Apr-10 00:00:00, C3: 234.45 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3853573534.758 km, ECC: 1.0799, INC: 8.63°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 179.798° , AP: 267.2245°, TA: 26.97°
#
#
#
# Launch: 2040-Sep-22 00:00:00, Arrival: 2106-May-10 00:00:00, C3: 245.49 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3870524449.536 km, ECC: 1.0739, INC: 8.85°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 182.285° , AP: 263.8190°, TA: 27.50°
#
#
#
# Launch: 2045-Dec-25 00:00:00, Arrival: 2111-Aug-12 00:00:00, C3: 246.12 km²/s², Time to reach Nose:  65.67 years
#
# Elements for JUPITER -> HELIOPAUSE → SMA: 3391579465.911 km, ECC: 1.0857, INC: 7.58°
#
# Elements JUPITER -> HELIOPAUSE → RAAN: 158.178° , AP: 289.0184°, TA: -27.11°
